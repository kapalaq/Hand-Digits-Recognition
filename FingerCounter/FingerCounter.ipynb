# %%
import cv2 as cv
import mediapipe as mp
import numpy as np
import os

from collections import namedtuple

# %%
mpHands = mp.solutions.hands
mpConnect = mp.solutions.hands_connections
mpDraw = mp.solutions.drawing_utils

# %%
def get_coordinates(hand: namedtuple) -> np.ndarray:
    """
    Converts NamedTuple of coordinates to numpy array
    :param hand: - output of mediapipe hand recognizer
    :return: flatten numpy array of coordinates
    """
    hand_arr = np.zeros(63)
    i = 0
    for el in hand.landmark:
        hand_arr[i] = el.x
        hand_arr[i + 1] = el.y
        hand_arr[i + 2] = el.z
        i += 3
    return hand_arr

# %%
def recognizer(frame: np.ndarray, model: mpHands.Hands) -> namedtuple:
    """
    Recognizing hands landmarks on frame
    :param frame: - np.ndarray representing hands landmarks
    :param model: - MediaPipe solution for hand recognition 
    :return: - NamedTuple of hands landmarks
    """
    image = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
    image.flags.writeable = False
    result = model.process(image).multi_hand_landmarks
    image.flags.writeable = True
    return result

# %% [markdown]
# # Data Collection

# %%
digits = np.array(["one", "two", "three", "four", "five"])
digits_map = {
    "one": 1,
    "two": 2,
    "three": 3,
    "four": 4,
    "five": 5
}
num_of_samples = 100
data = os.path.join("data")

# %%
def create_folders(path: str, targets: np.ndarray) -> None:
    """
    Creates folders for each target if they do not exist
    :param path: - data folder path
    :param targets: - array of classification targets
    :return: 
    """
    for target in targets:
        new_path = os.path.join(path, target)
        os.mkdir(new_path)

# %%
create_folders(data, digits)

# %%
def collect_images():
    """
    Collect data samples in numpy array format (.npy files)
    :return:
    """
    webcam = cv.VideoCapture(0)
    if not webcam.isOpened():
        print("Error: Camera not found.")
        return
    
    print("Press 's' to start capturing images, and 'q' to quit.")
    try:
        with mpHands.Hands(max_num_hands=1) as mp_hands:
            for digit in digits:
                print(f"Get ready to show '{digit}' gesture.")
                input("Press Enter when ready.")
                count = 0
                while count < num_of_samples:
                    ret, frame = webcam.read()
                    if not ret:
                        print("Failed to grab frame.")
                        break
                    if count == 0:
                        cv.putText(frame, 'Press \'s\' to start capturing '
                                          'images, and \'q\' to quit.', (50,200),
                                   cv.FONT_HERSHEY_SIMPLEX, 0.7, (240, 240, 240), 1, cv.LINE_AA)
                    cv.putText(frame, f'Collecting frames for {digit}'
                                      f' Video Number {count + 1}', (15,12), 
                               cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, 
                               cv.LINE_AA)
                    
                    result = recognizer(frame, mp_hands)
                    if result is not None:
                        mpDraw.draw_landmarks(frame, result[0], 
                                              mpConnect.HAND_CONNECTIONS)
                    
                    cv.imshow("webcam", frame)
                    key = cv.waitKey(1) & 0xFF
                    if key == ord('s') and result is not None:
                        npy_data = get_coordinates(hand=result[0])
                        filename = os.path.join(data, digit, f"{count + 1}.npy")
                        np.save(filename, npy_data)
        
                        print(f"Saved {filename}")
                        count += 1
        
                    elif key == ord('q'):
                        print("Exiting early.")
                        break
    except Exception as e:
        print(e)
    finally:
        webcam.release()
        cv.destroyAllWindows()

# %%
collect_images()
# Out:
# Press 's' to start capturing images, and 'q' to quit.
# Get ready to show 'one' gesture.
# Saved data\one\1.npy
# Saved data\one\2.npy
# Saved data\one\3.npy
# Saved data\one\4.npy
# Saved data\one\5.npy
# Saved data\one\6.npy
# Saved data\one\7.npy
# Saved data\one\8.npy
# Saved data\one\9.npy
# Saved data\one\10.npy
# Saved data\one\11.npy
# Saved data\one\12.npy
# Saved data\one\13.npy
# Saved data\one\14.npy
# Saved data\one\15.npy
# Saved data\one\16.npy
# Saved data\one\17.npy
# Saved data\one\18.npy
# Saved data\one\19.npy
# Saved data\one\20.npy
# Saved data\one\21.npy
# Saved data\one\22.npy
# Saved data\one\23.npy
# Saved data\one\24.npy
# Saved data\one\25.npy
# Saved data\one\26.npy
# Saved data\one\27.npy
# Saved data\one\28.npy
# Saved data\one\29.npy
# Saved data\one\30.npy
# Saved data\one\31.npy
# Saved data\one\32.npy
# Saved data\one\33.npy
# Saved data\one\34.npy
# Saved data\one\35.npy
# Saved data\one\36.npy
# Saved data\one\37.npy
# Saved data\one\38.npy
# Saved data\one\39.npy
# Saved data\one\40.npy
# Saved data\one\41.npy
# Saved data\one\42.npy
# Saved data\one\43.npy
# Saved data\one\44.npy
# Saved data\one\45.npy
# Saved data\one\46.npy
# Saved data\one\47.npy
# Saved data\one\48.npy
# Saved data\one\49.npy
# Saved data\one\50.npy
# Saved data\one\51.npy
# Saved data\one\52.npy
# Saved data\one\53.npy
# Saved data\one\54.npy
# Saved data\one\55.npy
# Saved data\one\56.npy
# Saved data\one\57.npy
# Saved data\one\58.npy
# Saved data\one\59.npy
# Saved data\one\60.npy
# Saved data\one\61.npy
# Saved data\one\62.npy
# Saved data\one\63.npy
# Saved data\one\64.npy
# Saved data\one\65.npy
# Saved data\one\66.npy
# Saved data\one\67.npy
# Saved data\one\68.npy
# Saved data\one\69.npy
# Saved data\one\70.npy
# Saved data\one\71.npy
# Saved data\one\72.npy
# Saved data\one\73.npy
# Saved data\one\74.npy
# Saved data\one\75.npy
# Saved data\one\76.npy
# Saved data\one\77.npy
# Saved data\one\78.npy
# Saved data\one\79.npy
# Saved data\one\80.npy
# Saved data\one\81.npy
# Saved data\one\82.npy
# Saved data\one\83.npy
# Saved data\one\84.npy
# Saved data\one\85.npy
# Saved data\one\86.npy
# Saved data\one\87.npy
# Saved data\one\88.npy
# Saved data\one\89.npy
# Saved data\one\90.npy
# Saved data\one\91.npy
# Saved data\one\92.npy
# Saved data\one\93.npy
# Saved data\one\94.npy
# Saved data\one\95.npy
# Saved data\one\96.npy
# Saved data\one\97.npy
# Saved data\one\98.npy
# Saved data\one\99.npy
# Saved data\one\100.npy
# Get ready to show 'two' gesture.
# Saved data\two\1.npy
# Saved data\two\2.npy
# Saved data\two\3.npy
# Saved data\two\4.npy
# Saved data\two\5.npy
# Saved data\two\6.npy
# Saved data\two\7.npy
# Saved data\two\8.npy
# Saved data\two\9.npy
# Saved data\two\10.npy
# Saved data\two\11.npy
# Saved data\two\12.npy
# Saved data\two\13.npy
# Saved data\two\14.npy
# Saved data\two\15.npy
# Saved data\two\16.npy
# Saved data\two\17.npy
# Saved data\two\18.npy
# Saved data\two\19.npy
# Saved data\two\20.npy
# Saved data\two\21.npy
# Saved data\two\22.npy
# Saved data\two\23.npy
# Saved data\two\24.npy
# Saved data\two\25.npy
# Saved data\two\26.npy
# Saved data\two\27.npy
# Saved data\two\28.npy
# Saved data\two\29.npy
# Saved data\two\30.npy
# Saved data\two\31.npy
# Saved data\two\32.npy
# Saved data\two\33.npy
# Saved data\two\34.npy
# Saved data\two\35.npy
# Saved data\two\36.npy
# Saved data\two\37.npy
# Saved data\two\38.npy
# Saved data\two\39.npy
# Saved data\two\40.npy
# Saved data\two\41.npy
# Saved data\two\42.npy
# Saved data\two\43.npy
# Saved data\two\44.npy
# Saved data\two\45.npy
# Saved data\two\46.npy
# Saved data\two\47.npy
# Saved data\two\48.npy
# Saved data\two\49.npy
# Saved data\two\50.npy
# Saved data\two\51.npy
# Saved data\two\52.npy
# Saved data\two\53.npy
# Saved data\two\54.npy
# Saved data\two\55.npy
# Saved data\two\56.npy
# Saved data\two\57.npy
# Saved data\two\58.npy
# Saved data\two\59.npy
# Saved data\two\60.npy
# Saved data\two\61.npy
# Saved data\two\62.npy
# Saved data\two\63.npy
# Saved data\two\64.npy
# Saved data\two\65.npy
# Saved data\two\66.npy
# Saved data\two\67.npy
# Saved data\two\68.npy
# Saved data\two\69.npy
# Saved data\two\70.npy
# Saved data\two\71.npy
# Saved data\two\72.npy
# Saved data\two\73.npy
# Saved data\two\74.npy
# Saved data\two\75.npy
# Saved data\two\76.npy
# Saved data\two\77.npy
# Saved data\two\78.npy
# Saved data\two\79.npy
# Saved data\two\80.npy
# Saved data\two\81.npy
# Saved data\two\82.npy
# Saved data\two\83.npy
# Saved data\two\84.npy
# Saved data\two\85.npy
# Saved data\two\86.npy
# Saved data\two\87.npy
# Saved data\two\88.npy
# Saved data\two\89.npy
# Saved data\two\90.npy
# Saved data\two\91.npy
# Saved data\two\92.npy
# Saved data\two\93.npy
# Saved data\two\94.npy
# Saved data\two\95.npy
# Saved data\two\96.npy
# Saved data\two\97.npy
# Saved data\two\98.npy
# Saved data\two\99.npy
# Saved data\two\100.npy
# Get ready to show 'three' gesture.
# Saved data\three\1.npy
# Saved data\three\2.npy
# Saved data\three\3.npy
# Saved data\three\4.npy
# Saved data\three\5.npy
# Saved data\three\6.npy
# Saved data\three\7.npy
# Saved data\three\8.npy
# Saved data\three\9.npy
# Saved data\three\10.npy
# Saved data\three\11.npy
# Saved data\three\12.npy
# Saved data\three\13.npy
# Saved data\three\14.npy
# Saved data\three\15.npy
# Saved data\three\16.npy
# Saved data\three\17.npy
# Saved data\three\18.npy
# Saved data\three\19.npy
# Saved data\three\20.npy
# Saved data\three\21.npy
# Saved data\three\22.npy
# Saved data\three\23.npy
# Saved data\three\24.npy
# Saved data\three\25.npy
# Saved data\three\26.npy
# Saved data\three\27.npy
# Saved data\three\28.npy
# Saved data\three\29.npy
# Saved data\three\30.npy
# Saved data\three\31.npy
# Saved data\three\32.npy
# Saved data\three\33.npy
# Saved data\three\34.npy
# Saved data\three\35.npy
# Saved data\three\36.npy
# Saved data\three\37.npy
# Saved data\three\38.npy
# Saved data\three\39.npy
# Saved data\three\40.npy
# Saved data\three\41.npy
# Saved data\three\42.npy
# Saved data\three\43.npy
# Saved data\three\44.npy
# Saved data\three\45.npy
# Saved data\three\46.npy
# Saved data\three\47.npy
# Saved data\three\48.npy
# Saved data\three\49.npy
# Saved data\three\50.npy
# Saved data\three\51.npy
# Saved data\three\52.npy
# Saved data\three\53.npy
# Saved data\three\54.npy
# Saved data\three\55.npy
# Saved data\three\56.npy
# Saved data\three\57.npy
# Saved data\three\58.npy
# Saved data\three\59.npy
# Saved data\three\60.npy
# Saved data\three\61.npy
# Saved data\three\62.npy
# Saved data\three\63.npy
# Saved data\three\64.npy
# Saved data\three\65.npy
# Saved data\three\66.npy
# Saved data\three\67.npy
# Saved data\three\68.npy
# Saved data\three\69.npy
# Saved data\three\70.npy
# Saved data\three\71.npy
# Saved data\three\72.npy
# Saved data\three\73.npy
# Saved data\three\74.npy
# Saved data\three\75.npy
# Saved data\three\76.npy
# Saved data\three\77.npy
# Saved data\three\78.npy
# Saved data\three\79.npy
# Saved data\three\80.npy
# Saved data\three\81.npy
# Saved data\three\82.npy
# Saved data\three\83.npy
# Saved data\three\84.npy
# Saved data\three\85.npy
# Saved data\three\86.npy
# Saved data\three\87.npy
# Saved data\three\88.npy
# Saved data\three\89.npy
# Saved data\three\90.npy
# Saved data\three\91.npy
# Saved data\three\92.npy
# Saved data\three\93.npy
# Saved data\three\94.npy
# Saved data\three\95.npy
# Saved data\three\96.npy
# Saved data\three\97.npy
# Saved data\three\98.npy
# Saved data\three\99.npy
# Saved data\three\100.npy
# Get ready to show 'four' gesture.
# Saved data\four\1.npy
# Saved data\four\2.npy
# Saved data\four\3.npy
# Saved data\four\4.npy
# Saved data\four\5.npy
# Saved data\four\6.npy
# Saved data\four\7.npy
# Saved data\four\8.npy
# Saved data\four\9.npy
# Saved data\four\10.npy
# Saved data\four\11.npy
# Saved data\four\12.npy
# Saved data\four\13.npy
# Saved data\four\14.npy
# Saved data\four\15.npy
# Saved data\four\16.npy
# Saved data\four\17.npy
# Saved data\four\18.npy
# Saved data\four\19.npy
# Saved data\four\20.npy
# Saved data\four\21.npy
# Saved data\four\22.npy
# Saved data\four\23.npy
# Saved data\four\24.npy
# Saved data\four\25.npy
# Saved data\four\26.npy
# Saved data\four\27.npy
# Saved data\four\28.npy
# Saved data\four\29.npy
# Saved data\four\30.npy
# Saved data\four\31.npy
# Saved data\four\32.npy
# Saved data\four\33.npy
# Saved data\four\34.npy
# Saved data\four\35.npy
# Saved data\four\36.npy
# Saved data\four\37.npy
# Saved data\four\38.npy
# Saved data\four\39.npy
# Saved data\four\40.npy
# Saved data\four\41.npy
# Saved data\four\42.npy
# Saved data\four\43.npy
# Saved data\four\44.npy
# Saved data\four\45.npy
# Saved data\four\46.npy
# Saved data\four\47.npy
# Saved data\four\48.npy
# Saved data\four\49.npy
# Saved data\four\50.npy
# Saved data\four\51.npy
# Saved data\four\52.npy
# Saved data\four\53.npy
# Saved data\four\54.npy
# Saved data\four\55.npy
# Saved data\four\56.npy
# Saved data\four\57.npy
# Saved data\four\58.npy
# Saved data\four\59.npy
# Saved data\four\60.npy
# Saved data\four\61.npy
# Saved data\four\62.npy
# Saved data\four\63.npy
# Saved data\four\64.npy
# Saved data\four\65.npy
# Saved data\four\66.npy
# Saved data\four\67.npy
# Saved data\four\68.npy
# Saved data\four\69.npy
# Saved data\four\70.npy
# Saved data\four\71.npy
# Saved data\four\72.npy
# Saved data\four\73.npy
# Saved data\four\74.npy
# Saved data\four\75.npy
# Saved data\four\76.npy
# Saved data\four\77.npy
# Saved data\four\78.npy
# Saved data\four\79.npy
# Saved data\four\80.npy
# Saved data\four\81.npy
# Saved data\four\82.npy
# Saved data\four\83.npy
# Saved data\four\84.npy
# Saved data\four\85.npy
# Saved data\four\86.npy
# Saved data\four\87.npy
# Saved data\four\88.npy
# Saved data\four\89.npy
# Saved data\four\90.npy
# Saved data\four\91.npy
# Saved data\four\92.npy
# Saved data\four\93.npy
# Saved data\four\94.npy
# Saved data\four\95.npy
# Saved data\four\96.npy
# Saved data\four\97.npy
# Saved data\four\98.npy
# Saved data\four\99.npy
# Saved data\four\100.npy
# Get ready to show 'five' gesture.
# Saved data\five\1.npy
# Saved data\five\2.npy
# Saved data\five\3.npy
# Saved data\five\4.npy
# Saved data\five\5.npy
# Saved data\five\6.npy
# Saved data\five\7.npy
# Saved data\five\8.npy
# Saved data\five\9.npy
# Saved data\five\10.npy
# Saved data\five\11.npy
# Saved data\five\12.npy
# Saved data\five\13.npy
# Saved data\five\14.npy
# Saved data\five\15.npy
# Saved data\five\16.npy
# Saved data\five\17.npy
# Saved data\five\18.npy
# Saved data\five\19.npy
# Saved data\five\20.npy
# Saved data\five\21.npy
# Saved data\five\22.npy
# Saved data\five\23.npy
# Saved data\five\24.npy
# Saved data\five\25.npy
# Saved data\five\26.npy
# Saved data\five\27.npy
# Saved data\five\28.npy
# Saved data\five\29.npy
# Saved data\five\30.npy
# Saved data\five\31.npy
# Saved data\five\32.npy
# Saved data\five\33.npy
# Saved data\five\34.npy
# Saved data\five\35.npy
# Saved data\five\36.npy
# Saved data\five\37.npy
# Saved data\five\38.npy
# Saved data\five\39.npy
# Saved data\five\40.npy
# Saved data\five\41.npy
# Saved data\five\42.npy
# Saved data\five\43.npy
# Saved data\five\44.npy
# Saved data\five\45.npy
# Saved data\five\46.npy
# Saved data\five\47.npy
# Saved data\five\48.npy
# Saved data\five\49.npy
# Saved data\five\50.npy
# Saved data\five\51.npy
# Saved data\five\52.npy
# Saved data\five\53.npy
# Saved data\five\54.npy
# Saved data\five\55.npy
# Saved data\five\56.npy
# Saved data\five\57.npy
# Saved data\five\58.npy
# Saved data\five\59.npy
# Saved data\five\60.npy
# Saved data\five\61.npy
# Saved data\five\62.npy
# Saved data\five\63.npy
# Saved data\five\64.npy
# Saved data\five\65.npy
# Saved data\five\66.npy
# Saved data\five\67.npy
# Saved data\five\68.npy
# Saved data\five\69.npy
# Saved data\five\70.npy
# Saved data\five\71.npy
# Saved data\five\72.npy
# Saved data\five\73.npy
# Saved data\five\74.npy
# Saved data\five\75.npy
# Saved data\five\76.npy
# Saved data\five\77.npy
# Saved data\five\78.npy
# Saved data\five\79.npy
# Saved data\five\80.npy
# Saved data\five\81.npy
# Saved data\five\82.npy
# Saved data\five\83.npy
# Saved data\five\84.npy
# Saved data\five\85.npy
# Saved data\five\86.npy
# Saved data\five\87.npy
# Saved data\five\88.npy
# Saved data\five\89.npy
# Saved data\five\90.npy
# Saved data\five\91.npy
# Saved data\five\92.npy
# Saved data\five\93.npy
# Saved data\five\94.npy
# Saved data\five\95.npy
# Saved data\five\96.npy
# Saved data\five\97.npy
# Saved data\five\98.npy
# Saved data\five\99.npy
# Saved data\five\100.npy

# %% [markdown]
# # Data Loading

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
digits = np.array(["one", "two", "three", "four", "five"])
digits_map = {
    "one": 1,
    "two": 2,
    "three": 3,
    "four": 4,
    "five": 5
}
num_of_samples = 100
data = os.path.join("data")

# %%
x_data, y_data = [], []
for digit in digits:
    for i in range(num_of_samples):
        arr = np.load(os.path.join(data, digit, f"{i + 1}.npy"))
        x_data.append(arr)
        y_data.append(digits_map[digit])
x_data = np.array(x_data)
y_data = OneHotEncoder().fit_transform(np.array(y_data).reshape(-1, 1)).toarray()
print("X_DATA:", x_data.shape)
print("Y_DATA:", y_data.shape)
# Out:
# X_DATA: (500, 63)
# Y_DATA: (500, 5)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.15, random_state=42)

# %% [markdown]
# # Model Initialization

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim import Adam

# %%
model = nn.Sequential(
        nn.Linear(63, 16),
        nn.ReLU(),
        nn.Linear(16, 5),
        nn.Softmax(dim=1)
    )

# %%
optimizer = Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
epochs = 500

# %%
dataset = TensorDataset(torch.tensor(x_data).float(), torch.tensor(y_data).float())
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
for epoch in range(epochs):
    running_loss = []
    for batch, (inputs, actual) in enumerate(dataloader):
        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, actual)
        running_loss.append(loss.item())
        loss.backward()
        optimizer.step()
        print(f"EPOCH {epoch + 1} === BATCH: {batch + 1} === LOSS: {loss.item()}")
    print(f"EPOCH {epoch + 1} LOSS: {np.mean(running_loss)}")
# Out:
# EPOCH 1 === BATCH: 1 === LOSS: 0.16110463440418243
# EPOCH 1 === BATCH: 2 === LOSS: 0.16104494035243988
# EPOCH 1 === BATCH: 3 === LOSS: 0.16175904870033264
# EPOCH 1 === BATCH: 4 === LOSS: 0.1627247929573059
# EPOCH 1 === BATCH: 5 === LOSS: 0.15988093614578247
# EPOCH 1 === BATCH: 6 === LOSS: 0.1597270667552948
# EPOCH 1 === BATCH: 7 === LOSS: 0.16200926899909973
# EPOCH 1 === BATCH: 8 === LOSS: 0.1600249856710434
# EPOCH 1 === BATCH: 9 === LOSS: 0.1596592515707016
# EPOCH 1 === BATCH: 10 === LOSS: 0.15907110273838043
# EPOCH 1 === BATCH: 11 === LOSS: 0.15757450461387634
# EPOCH 1 === BATCH: 12 === LOSS: 0.1607411801815033
# EPOCH 1 === BATCH: 13 === LOSS: 0.15908324718475342
# EPOCH 1 === BATCH: 14 === LOSS: 0.16088569164276123
# EPOCH 1 === BATCH: 15 === LOSS: 0.16136077046394348
# EPOCH 1 === BATCH: 16 === LOSS: 0.16319260001182556
# EPOCH 1 LOSS: 0.16061525139957666
# EPOCH 2 === BATCH: 1 === LOSS: 0.16072580218315125
# EPOCH 2 === BATCH: 2 === LOSS: 0.1616397202014923
# EPOCH 2 === BATCH: 3 === LOSS: 0.15959659218788147
# EPOCH 2 === BATCH: 4 === LOSS: 0.16220122575759888
# EPOCH 2 === BATCH: 5 === LOSS: 0.16120383143424988
# EPOCH 2 === BATCH: 6 === LOSS: 0.159511998295784
# EPOCH 2 === BATCH: 7 === LOSS: 0.1591217815876007
# EPOCH 2 === BATCH: 8 === LOSS: 0.15966591238975525
# EPOCH 2 === BATCH: 9 === LOSS: 0.1571180671453476
# EPOCH 2 === BATCH: 10 === LOSS: 0.15838736295700073
# EPOCH 2 === BATCH: 11 === LOSS: 0.1590399444103241
# EPOCH 2 === BATCH: 12 === LOSS: 0.16046050190925598
# EPOCH 2 === BATCH: 13 === LOSS: 0.15879762172698975
# EPOCH 2 === BATCH: 14 === LOSS: 0.1601043939590454
# EPOCH 2 === BATCH: 15 === LOSS: 0.15817560255527496
# EPOCH 2 === BATCH: 16 === LOSS: 0.1592368185520172
# EPOCH 2 LOSS: 0.1596866985782981
# EPOCH 3 === BATCH: 1 === LOSS: 0.16138426959514618
# EPOCH 3 === BATCH: 2 === LOSS: 0.15626689791679382
# EPOCH 3 === BATCH: 3 === LOSS: 0.15753859281539917
# EPOCH 3 === BATCH: 4 === LOSS: 0.1571710854768753
# EPOCH 3 === BATCH: 5 === LOSS: 0.15894722938537598
# EPOCH 3 === BATCH: 6 === LOSS: 0.158697247505188
# EPOCH 3 === BATCH: 7 === LOSS: 0.1598716676235199
# EPOCH 3 === BATCH: 8 === LOSS: 0.15782994031906128
# EPOCH 3 === BATCH: 9 === LOSS: 0.1607198566198349
# EPOCH 3 === BATCH: 10 === LOSS: 0.15883831679821014
# EPOCH 3 === BATCH: 11 === LOSS: 0.16000521183013916
# EPOCH 3 === BATCH: 12 === LOSS: 0.1569548398256302
# EPOCH 3 === BATCH: 13 === LOSS: 0.15969689190387726
# EPOCH 3 === BATCH: 14 === LOSS: 0.1595396250486374
# EPOCH 3 === BATCH: 15 === LOSS: 0.16013476252555847
# EPOCH 3 === BATCH: 16 === LOSS: 0.15826936066150665
# EPOCH 3 LOSS: 0.1588666122406721
# EPOCH 4 === BATCH: 1 === LOSS: 0.1595815122127533
# EPOCH 4 === BATCH: 2 === LOSS: 0.1572578102350235
# EPOCH 4 === BATCH: 3 === LOSS: 0.15757957100868225
# EPOCH 4 === BATCH: 4 === LOSS: 0.15740981698036194
# EPOCH 4 === BATCH: 5 === LOSS: 0.1597420871257782
# EPOCH 4 === BATCH: 6 === LOSS: 0.15803265571594238
# EPOCH 4 === BATCH: 7 === LOSS: 0.15752843022346497
# EPOCH 4 === BATCH: 8 === LOSS: 0.15893208980560303
# EPOCH 4 === BATCH: 9 === LOSS: 0.15821607410907745
# EPOCH 4 === BATCH: 10 === LOSS: 0.15768122673034668
# EPOCH 4 === BATCH: 11 === LOSS: 0.15828830003738403
# EPOCH 4 === BATCH: 12 === LOSS: 0.15777704119682312
# EPOCH 4 === BATCH: 13 === LOSS: 0.15736861526966095
# EPOCH 4 === BATCH: 14 === LOSS: 0.15671810507774353
# EPOCH 4 === BATCH: 15 === LOSS: 0.15603239834308624
# EPOCH 4 === BATCH: 16 === LOSS: 0.15884196758270264
# EPOCH 4 LOSS: 0.15793673135340214
# EPOCH 5 === BATCH: 1 === LOSS: 0.15838679671287537
# EPOCH 5 === BATCH: 2 === LOSS: 0.15696009993553162
# EPOCH 5 === BATCH: 3 === LOSS: 0.1572185456752777
# EPOCH 5 === BATCH: 4 === LOSS: 0.15627458691596985
# EPOCH 5 === BATCH: 5 === LOSS: 0.15677721798419952
# EPOCH 5 === BATCH: 6 === LOSS: 0.15666405856609344
# EPOCH 5 === BATCH: 7 === LOSS: 0.1571609079837799
# EPOCH 5 === BATCH: 8 === LOSS: 0.1571568250656128
# EPOCH 5 === BATCH: 9 === LOSS: 0.1551487147808075
# EPOCH 5 === BATCH: 10 === LOSS: 0.15716050565242767
# EPOCH 5 === BATCH: 11 === LOSS: 0.15678003430366516
# EPOCH 5 === BATCH: 12 === LOSS: 0.1554037481546402
# EPOCH 5 === BATCH: 13 === LOSS: 0.1572154313325882
# EPOCH 5 === BATCH: 14 === LOSS: 0.15718606114387512
# EPOCH 5 === BATCH: 15 === LOSS: 0.15820854902267456
# EPOCH 5 === BATCH: 16 === LOSS: 0.15652531385421753
# EPOCH 5 LOSS: 0.15688921231776476
# EPOCH 6 === BATCH: 1 === LOSS: 0.15530523657798767
# EPOCH 6 === BATCH: 2 === LOSS: 0.15672846138477325
# EPOCH 6 === BATCH: 3 === LOSS: 0.15715797245502472
# EPOCH 6 === BATCH: 4 === LOSS: 0.15679730474948883
# EPOCH 6 === BATCH: 5 === LOSS: 0.15559393167495728
# EPOCH 6 === BATCH: 6 === LOSS: 0.15400730073451996
# EPOCH 6 === BATCH: 7 === LOSS: 0.15376323461532593
# EPOCH 6 === BATCH: 8 === LOSS: 0.15504610538482666
# EPOCH 6 === BATCH: 9 === LOSS: 0.15613241493701935
# EPOCH 6 === BATCH: 10 === LOSS: 0.15817882120609283
# EPOCH 6 === BATCH: 11 === LOSS: 0.15567994117736816
# EPOCH 6 === BATCH: 12 === LOSS: 0.15519240498542786
# EPOCH 6 === BATCH: 13 === LOSS: 0.1573602855205536
# EPOCH 6 === BATCH: 14 === LOSS: 0.1555003821849823
# EPOCH 6 === BATCH: 15 === LOSS: 0.15556269884109497
# EPOCH 6 === BATCH: 16 === LOSS: 0.15219709277153015
# EPOCH 6 LOSS: 0.15563772432506084
# EPOCH 7 === BATCH: 1 === LOSS: 0.15537990629673004
# EPOCH 7 === BATCH: 2 === LOSS: 0.15345445275306702
# EPOCH 7 === BATCH: 3 === LOSS: 0.15352949500083923
# EPOCH 7 === BATCH: 4 === LOSS: 0.15368911623954773
# EPOCH 7 === BATCH: 5 === LOSS: 0.1545102745294571
# EPOCH 7 === BATCH: 6 === LOSS: 0.15809139609336853
# EPOCH 7 === BATCH: 7 === LOSS: 0.15284106135368347
# EPOCH 7 === BATCH: 8 === LOSS: 0.15483641624450684
# EPOCH 7 === BATCH: 9 === LOSS: 0.15467193722724915
# EPOCH 7 === BATCH: 10 === LOSS: 0.1558598279953003
# EPOCH 7 === BATCH: 11 === LOSS: 0.15442310273647308
# EPOCH 7 === BATCH: 12 === LOSS: 0.15405921638011932
# EPOCH 7 === BATCH: 13 === LOSS: 0.15191498398780823
# EPOCH 7 === BATCH: 14 === LOSS: 0.15371565520763397
# EPOCH 7 === BATCH: 15 === LOSS: 0.1544804573059082
# EPOCH 7 === BATCH: 16 === LOSS: 0.15491700172424316
# EPOCH 7 LOSS: 0.15439839381724596
# EPOCH 8 === BATCH: 1 === LOSS: 0.1522853523492813
# EPOCH 8 === BATCH: 2 === LOSS: 0.14944832026958466
# EPOCH 8 === BATCH: 3 === LOSS: 0.15415064990520477
# EPOCH 8 === BATCH: 4 === LOSS: 0.15370993316173553
# EPOCH 8 === BATCH: 5 === LOSS: 0.15255621075630188
# EPOCH 8 === BATCH: 6 === LOSS: 0.15383438766002655
# EPOCH 8 === BATCH: 7 === LOSS: 0.15636861324310303
# EPOCH 8 === BATCH: 8 === LOSS: 0.14994749426841736
# EPOCH 8 === BATCH: 9 === LOSS: 0.15661300718784332
# EPOCH 8 === BATCH: 10 === LOSS: 0.15261511504650116
# EPOCH 8 === BATCH: 11 === LOSS: 0.14901801943778992
# EPOCH 8 === BATCH: 12 === LOSS: 0.15136635303497314
# EPOCH 8 === BATCH: 13 === LOSS: 0.1536879688501358
# EPOCH 8 === BATCH: 14 === LOSS: 0.15314258635044098
# EPOCH 8 === BATCH: 15 === LOSS: 0.15336351096630096
# EPOCH 8 === BATCH: 16 === LOSS: 0.15407338738441467
# EPOCH 8 LOSS: 0.15288630686700344
# EPOCH 9 === BATCH: 1 === LOSS: 0.15142695605754852
# EPOCH 9 === BATCH: 2 === LOSS: 0.1535767763853073
# EPOCH 9 === BATCH: 3 === LOSS: 0.15293379127979279
# EPOCH 9 === BATCH: 4 === LOSS: 0.14969897270202637
# EPOCH 9 === BATCH: 5 === LOSS: 0.14883454144001007
# EPOCH 9 === BATCH: 6 === LOSS: 0.15072211623191833
# EPOCH 9 === BATCH: 7 === LOSS: 0.14929132163524628
# EPOCH 9 === BATCH: 8 === LOSS: 0.15042951703071594
# EPOCH 9 === BATCH: 9 === LOSS: 0.15073136985301971
# EPOCH 9 === BATCH: 10 === LOSS: 0.1535477340221405
# EPOCH 9 === BATCH: 11 === LOSS: 0.14914900064468384
# EPOCH 9 === BATCH: 12 === LOSS: 0.15323099493980408
# EPOCH 9 === BATCH: 13 === LOSS: 0.15310510993003845
# EPOCH 9 === BATCH: 14 === LOSS: 0.14934854209423065
# EPOCH 9 === BATCH: 15 === LOSS: 0.15141257643699646
# EPOCH 9 === BATCH: 16 === LOSS: 0.15393979847431183
# EPOCH 9 LOSS: 0.15133619494736195
# EPOCH 10 === BATCH: 1 === LOSS: 0.1490638256072998
# EPOCH 10 === BATCH: 2 === LOSS: 0.15649566054344177
# EPOCH 10 === BATCH: 3 === LOSS: 0.14628851413726807
# EPOCH 10 === BATCH: 4 === LOSS: 0.1486310213804245
# EPOCH 10 === BATCH: 5 === LOSS: 0.14976315200328827
# EPOCH 10 === BATCH: 6 === LOSS: 0.14303460717201233
# EPOCH 10 === BATCH: 7 === LOSS: 0.14883650839328766
# EPOCH 10 === BATCH: 8 === LOSS: 0.15087619423866272
# EPOCH 10 === BATCH: 9 === LOSS: 0.14849083125591278
# EPOCH 10 === BATCH: 10 === LOSS: 0.15124107897281647
# EPOCH 10 === BATCH: 11 === LOSS: 0.1473151594400406
# EPOCH 10 === BATCH: 12 === LOSS: 0.1505899876356125
# EPOCH 10 === BATCH: 13 === LOSS: 0.14716920256614685
# EPOCH 10 === BATCH: 14 === LOSS: 0.15368559956550598
# EPOCH 10 === BATCH: 15 === LOSS: 0.150853231549263
# EPOCH 10 === BATCH: 16 === LOSS: 0.14792722463607788
# EPOCH 10 LOSS: 0.14939136244356632
# EPOCH 11 === BATCH: 1 === LOSS: 0.1490504890680313
# EPOCH 11 === BATCH: 2 === LOSS: 0.14266355335712433
# EPOCH 11 === BATCH: 3 === LOSS: 0.14851582050323486
# EPOCH 11 === BATCH: 4 === LOSS: 0.1547258049249649
# EPOCH 11 === BATCH: 5 === LOSS: 0.15434540808200836
# EPOCH 11 === BATCH: 6 === LOSS: 0.145677849650383
# EPOCH 11 === BATCH: 7 === LOSS: 0.15187445282936096
# EPOCH 11 === BATCH: 8 === LOSS: 0.1479431688785553
# EPOCH 11 === BATCH: 9 === LOSS: 0.15080980956554413
# EPOCH 11 === BATCH: 10 === LOSS: 0.1463707685470581
# EPOCH 11 === BATCH: 11 === LOSS: 0.14653995633125305
# EPOCH 11 === BATCH: 12 === LOSS: 0.147785484790802
# EPOCH 11 === BATCH: 13 === LOSS: 0.14244413375854492
# EPOCH 11 === BATCH: 14 === LOSS: 0.14920379221439362
# EPOCH 11 === BATCH: 15 === LOSS: 0.13835814595222473
# EPOCH 11 === BATCH: 16 === LOSS: 0.15170522034168243
# EPOCH 11 LOSS: 0.14800086617469788
# EPOCH 12 === BATCH: 1 === LOSS: 0.15107408165931702
# EPOCH 12 === BATCH: 2 === LOSS: 0.1493624448776245
# EPOCH 12 === BATCH: 3 === LOSS: 0.14408765733242035
# EPOCH 12 === BATCH: 4 === LOSS: 0.14844241738319397
# EPOCH 12 === BATCH: 5 === LOSS: 0.1431361436843872
# EPOCH 12 === BATCH: 6 === LOSS: 0.14659380912780762
# EPOCH 12 === BATCH: 7 === LOSS: 0.14345407485961914
# EPOCH 12 === BATCH: 8 === LOSS: 0.13930101692676544
# EPOCH 12 === BATCH: 9 === LOSS: 0.14831729233264923
# EPOCH 12 === BATCH: 10 === LOSS: 0.14535187184810638
# EPOCH 12 === BATCH: 11 === LOSS: 0.14438311755657196
# EPOCH 12 === BATCH: 12 === LOSS: 0.14764629304409027
# EPOCH 12 === BATCH: 13 === LOSS: 0.1450299620628357
# EPOCH 12 === BATCH: 14 === LOSS: 0.14958089590072632
# EPOCH 12 === BATCH: 15 === LOSS: 0.1454610675573349
# EPOCH 12 === BATCH: 16 === LOSS: 0.147020161151886
# EPOCH 12 LOSS: 0.1461401442065835
# EPOCH 13 === BATCH: 1 === LOSS: 0.1486053168773651
# EPOCH 13 === BATCH: 2 === LOSS: 0.14594370126724243
# EPOCH 13 === BATCH: 3 === LOSS: 0.14673981070518494
# EPOCH 13 === BATCH: 4 === LOSS: 0.1482289731502533
# EPOCH 13 === BATCH: 5 === LOSS: 0.14648941159248352
# EPOCH 13 === BATCH: 6 === LOSS: 0.14206485450267792
# EPOCH 13 === BATCH: 7 === LOSS: 0.14458146691322327
# EPOCH 13 === BATCH: 8 === LOSS: 0.1425532102584839
# EPOCH 13 === BATCH: 9 === LOSS: 0.14306339621543884
# EPOCH 13 === BATCH: 10 === LOSS: 0.13705424964427948
# EPOCH 13 === BATCH: 11 === LOSS: 0.14655590057373047
# EPOCH 13 === BATCH: 12 === LOSS: 0.13988471031188965
# EPOCH 13 === BATCH: 13 === LOSS: 0.14578887820243835
# EPOCH 13 === BATCH: 14 === LOSS: 0.1472572386264801
# EPOCH 13 === BATCH: 15 === LOSS: 0.14604870975017548
# EPOCH 13 === BATCH: 16 === LOSS: 0.13741044700145721
# EPOCH 13 LOSS: 0.14426689222455025
# EPOCH 14 === BATCH: 1 === LOSS: 0.14563599228858948
# EPOCH 14 === BATCH: 2 === LOSS: 0.14118829369544983
# EPOCH 14 === BATCH: 3 === LOSS: 0.1408470869064331
# EPOCH 14 === BATCH: 4 === LOSS: 0.14253829419612885
# EPOCH 14 === BATCH: 5 === LOSS: 0.14532794058322906
# EPOCH 14 === BATCH: 6 === LOSS: 0.1468929648399353
# EPOCH 14 === BATCH: 7 === LOSS: 0.14827404916286469
# EPOCH 14 === BATCH: 8 === LOSS: 0.13768479228019714
# EPOCH 14 === BATCH: 9 === LOSS: 0.14428307116031647
# EPOCH 14 === BATCH: 10 === LOSS: 0.1435205638408661
# EPOCH 14 === BATCH: 11 === LOSS: 0.13836534321308136
# EPOCH 14 === BATCH: 12 === LOSS: 0.13930854201316833
# EPOCH 14 === BATCH: 13 === LOSS: 0.14117634296417236
# EPOCH 14 === BATCH: 14 === LOSS: 0.14327163994312286
# EPOCH 14 === BATCH: 15 === LOSS: 0.1461518108844757
# EPOCH 14 === BATCH: 16 === LOSS: 0.1351577341556549
# EPOCH 14 LOSS: 0.14247652888298035
# EPOCH 15 === BATCH: 1 === LOSS: 0.14350011944770813
# EPOCH 15 === BATCH: 2 === LOSS: 0.14553692936897278
# EPOCH 15 === BATCH: 3 === LOSS: 0.1467660665512085
# EPOCH 15 === BATCH: 4 === LOSS: 0.14406274259090424
# EPOCH 15 === BATCH: 5 === LOSS: 0.13477656245231628
# EPOCH 15 === BATCH: 6 === LOSS: 0.13943582773208618
# EPOCH 15 === BATCH: 7 === LOSS: 0.14635534584522247
# EPOCH 15 === BATCH: 8 === LOSS: 0.1384083479642868
# EPOCH 15 === BATCH: 9 === LOSS: 0.14207182824611664
# EPOCH 15 === BATCH: 10 === LOSS: 0.13415715098381042
# EPOCH 15 === BATCH: 11 === LOSS: 0.13890022039413452
# EPOCH 15 === BATCH: 12 === LOSS: 0.13797630369663239
# EPOCH 15 === BATCH: 13 === LOSS: 0.1431082934141159
# EPOCH 15 === BATCH: 14 === LOSS: 0.13946864008903503
# EPOCH 15 === BATCH: 15 === LOSS: 0.14725534617900848
# EPOCH 15 === BATCH: 16 === LOSS: 0.13140921294689178
# EPOCH 15 LOSS: 0.14082430861890316
# EPOCH 16 === BATCH: 1 === LOSS: 0.13884331285953522
# EPOCH 16 === BATCH: 2 === LOSS: 0.139399453997612
# EPOCH 16 === BATCH: 3 === LOSS: 0.12402483075857162
# EPOCH 16 === BATCH: 4 === LOSS: 0.13919886946678162
# EPOCH 16 === BATCH: 5 === LOSS: 0.14202600717544556
# EPOCH 16 === BATCH: 6 === LOSS: 0.13387390971183777
# EPOCH 16 === BATCH: 7 === LOSS: 0.13825418055057526
# EPOCH 16 === BATCH: 8 === LOSS: 0.1446966677904129
# EPOCH 16 === BATCH: 9 === LOSS: 0.13073338568210602
# EPOCH 16 === BATCH: 10 === LOSS: 0.15237705409526825
# EPOCH 16 === BATCH: 11 === LOSS: 0.1285722851753235
# EPOCH 16 === BATCH: 12 === LOSS: 0.153206005692482
# EPOCH 16 === BATCH: 13 === LOSS: 0.14866892993450165
# EPOCH 16 === BATCH: 14 === LOSS: 0.1342635303735733
# EPOCH 16 === BATCH: 15 === LOSS: 0.14091622829437256
# EPOCH 16 === BATCH: 16 === LOSS: 0.1425664871931076
# EPOCH 16 LOSS: 0.13947632117196918
# EPOCH 17 === BATCH: 1 === LOSS: 0.13874025642871857
# EPOCH 17 === BATCH: 2 === LOSS: 0.1451376974582672
# EPOCH 17 === BATCH: 3 === LOSS: 0.12506680190563202
# EPOCH 17 === BATCH: 4 === LOSS: 0.1374155580997467
# EPOCH 17 === BATCH: 5 === LOSS: 0.13703890144824982
# EPOCH 17 === BATCH: 6 === LOSS: 0.14844338595867157
# EPOCH 17 === BATCH: 7 === LOSS: 0.14353199303150177
# EPOCH 17 === BATCH: 8 === LOSS: 0.14232617616653442
# EPOCH 17 === BATCH: 9 === LOSS: 0.1426657885313034
# EPOCH 17 === BATCH: 10 === LOSS: 0.14167267084121704
# EPOCH 17 === BATCH: 11 === LOSS: 0.14084506034851074
# EPOCH 17 === BATCH: 12 === LOSS: 0.1347493976354599
# EPOCH 17 === BATCH: 13 === LOSS: 0.12157972157001495
# EPOCH 17 === BATCH: 14 === LOSS: 0.14268359541893005
# EPOCH 17 === BATCH: 15 === LOSS: 0.13539893925189972
# EPOCH 17 === BATCH: 16 === LOSS: 0.12715479731559753
# EPOCH 17 LOSS: 0.13777817133814096
# EPOCH 18 === BATCH: 1 === LOSS: 0.13617613911628723
# EPOCH 18 === BATCH: 2 === LOSS: 0.14867019653320312
# EPOCH 18 === BATCH: 3 === LOSS: 0.13818374276161194
# EPOCH 18 === BATCH: 4 === LOSS: 0.1293395757675171
# EPOCH 18 === BATCH: 5 === LOSS: 0.1335129290819168
# EPOCH 18 === BATCH: 6 === LOSS: 0.1274949610233307
# EPOCH 18 === BATCH: 7 === LOSS: 0.12642712891101837
# EPOCH 18 === BATCH: 8 === LOSS: 0.14106038212776184
# EPOCH 18 === BATCH: 9 === LOSS: 0.13411109149456024
# EPOCH 18 === BATCH: 10 === LOSS: 0.13758349418640137
# EPOCH 18 === BATCH: 11 === LOSS: 0.145248681306839
# EPOCH 18 === BATCH: 12 === LOSS: 0.14089971780776978
# EPOCH 18 === BATCH: 13 === LOSS: 0.1390644758939743
# EPOCH 18 === BATCH: 14 === LOSS: 0.13174645602703094
# EPOCH 18 === BATCH: 15 === LOSS: 0.13551625609397888
# EPOCH 18 === BATCH: 16 === LOSS: 0.1265067309141159
# EPOCH 18 LOSS: 0.13572137244045734
# EPOCH 19 === BATCH: 1 === LOSS: 0.13238844275474548
# EPOCH 19 === BATCH: 2 === LOSS: 0.14047205448150635
# EPOCH 19 === BATCH: 3 === LOSS: 0.12739408016204834
# EPOCH 19 === BATCH: 4 === LOSS: 0.12539805471897125
# EPOCH 19 === BATCH: 5 === LOSS: 0.13700754940509796
# EPOCH 19 === BATCH: 6 === LOSS: 0.1407373696565628
# EPOCH 19 === BATCH: 7 === LOSS: 0.13105541467666626
# EPOCH 19 === BATCH: 8 === LOSS: 0.1380125880241394
# EPOCH 19 === BATCH: 9 === LOSS: 0.13711604475975037
# EPOCH 19 === BATCH: 10 === LOSS: 0.14111359417438507
# EPOCH 19 === BATCH: 11 === LOSS: 0.1355900764465332
# EPOCH 19 === BATCH: 12 === LOSS: 0.12797504663467407
# EPOCH 19 === BATCH: 13 === LOSS: 0.13197919726371765
# EPOCH 19 === BATCH: 14 === LOSS: 0.1290382295846939
# EPOCH 19 === BATCH: 15 === LOSS: 0.1316329538822174
# EPOCH 19 === BATCH: 16 === LOSS: 0.14373771846294403
# EPOCH 19 LOSS: 0.13441552594304085
# EPOCH 20 === BATCH: 1 === LOSS: 0.14639222621917725
# EPOCH 20 === BATCH: 2 === LOSS: 0.123859703540802
# EPOCH 20 === BATCH: 3 === LOSS: 0.13690993189811707
# EPOCH 20 === BATCH: 4 === LOSS: 0.1250735968351364
# EPOCH 20 === BATCH: 5 === LOSS: 0.1336948722600937
# EPOCH 20 === BATCH: 6 === LOSS: 0.13430938124656677
# EPOCH 20 === BATCH: 7 === LOSS: 0.13288649916648865
# EPOCH 20 === BATCH: 8 === LOSS: 0.13800711929798126
# EPOCH 20 === BATCH: 9 === LOSS: 0.1323167383670807
# EPOCH 20 === BATCH: 10 === LOSS: 0.13914018869400024
# EPOCH 20 === BATCH: 11 === LOSS: 0.13568845391273499
# EPOCH 20 === BATCH: 12 === LOSS: 0.13309665024280548
# EPOCH 20 === BATCH: 13 === LOSS: 0.12247172743082047
# EPOCH 20 === BATCH: 14 === LOSS: 0.1316949874162674
# EPOCH 20 === BATCH: 15 === LOSS: 0.12367065250873566
# EPOCH 20 === BATCH: 16 === LOSS: 0.12681256234645844
# EPOCH 20 LOSS: 0.13225158071145415
# EPOCH 21 === BATCH: 1 === LOSS: 0.14840519428253174
# EPOCH 21 === BATCH: 2 === LOSS: 0.12422678619623184
# EPOCH 21 === BATCH: 3 === LOSS: 0.13532941043376923
# EPOCH 21 === BATCH: 4 === LOSS: 0.12372871488332748
# EPOCH 21 === BATCH: 5 === LOSS: 0.12123869359493256
# EPOCH 21 === BATCH: 6 === LOSS: 0.11872180551290512
# EPOCH 21 === BATCH: 7 === LOSS: 0.13323725759983063
# EPOCH 21 === BATCH: 8 === LOSS: 0.13694535195827484
# EPOCH 21 === BATCH: 9 === LOSS: 0.12758176028728485
# EPOCH 21 === BATCH: 10 === LOSS: 0.13770386576652527
# EPOCH 21 === BATCH: 11 === LOSS: 0.12755538523197174
# EPOCH 21 === BATCH: 12 === LOSS: 0.12895461916923523
# EPOCH 21 === BATCH: 13 === LOSS: 0.13866004347801208
# EPOCH 21 === BATCH: 14 === LOSS: 0.12938374280929565
# EPOCH 21 === BATCH: 15 === LOSS: 0.13481685519218445
# EPOCH 21 === BATCH: 16 === LOSS: 0.125092551112175
# EPOCH 21 LOSS: 0.13072387734428048
# EPOCH 22 === BATCH: 1 === LOSS: 0.12892583012580872
# EPOCH 22 === BATCH: 2 === LOSS: 0.1261219084262848
# EPOCH 22 === BATCH: 3 === LOSS: 0.1284283697605133
# EPOCH 22 === BATCH: 4 === LOSS: 0.13713930547237396
# EPOCH 22 === BATCH: 5 === LOSS: 0.13058553636074066
# EPOCH 22 === BATCH: 6 === LOSS: 0.136123925447464
# EPOCH 22 === BATCH: 7 === LOSS: 0.13144806027412415
# EPOCH 22 === BATCH: 8 === LOSS: 0.11744008958339691
# EPOCH 22 === BATCH: 9 === LOSS: 0.13992467522621155
# EPOCH 22 === BATCH: 10 === LOSS: 0.11495038121938705
# EPOCH 22 === BATCH: 11 === LOSS: 0.13412317633628845
# EPOCH 22 === BATCH: 12 === LOSS: 0.13488154113292694
# EPOCH 22 === BATCH: 13 === LOSS: 0.13368406891822815
# EPOCH 22 === BATCH: 14 === LOSS: 0.12410436570644379
# EPOCH 22 === BATCH: 15 === LOSS: 0.12231770902872086
# EPOCH 22 === BATCH: 16 === LOSS: 0.11319047957658768
# EPOCH 22 LOSS: 0.1283368389122188
# EPOCH 23 === BATCH: 1 === LOSS: 0.12377478182315826
# EPOCH 23 === BATCH: 2 === LOSS: 0.12669144570827484
# EPOCH 23 === BATCH: 3 === LOSS: 0.13081403076648712
# EPOCH 23 === BATCH: 4 === LOSS: 0.13630890846252441
# EPOCH 23 === BATCH: 5 === LOSS: 0.12077174335718155
# EPOCH 23 === BATCH: 6 === LOSS: 0.1269395500421524
# EPOCH 23 === BATCH: 7 === LOSS: 0.11526934802532196
# EPOCH 23 === BATCH: 8 === LOSS: 0.12013666331768036
# EPOCH 23 === BATCH: 9 === LOSS: 0.12893646955490112
# EPOCH 23 === BATCH: 10 === LOSS: 0.13614413142204285
# EPOCH 23 === BATCH: 11 === LOSS: 0.12745359539985657
# EPOCH 23 === BATCH: 12 === LOSS: 0.14543655514717102
# EPOCH 23 === BATCH: 13 === LOSS: 0.1257452666759491
# EPOCH 23 === BATCH: 14 === LOSS: 0.11752192676067352
# EPOCH 23 === BATCH: 15 === LOSS: 0.11991097033023834
# EPOCH 23 === BATCH: 16 === LOSS: 0.13250815868377686
# EPOCH 23 LOSS: 0.1271477215923369
# EPOCH 24 === BATCH: 1 === LOSS: 0.11644484102725983
# EPOCH 24 === BATCH: 2 === LOSS: 0.1139945536851883
# EPOCH 24 === BATCH: 3 === LOSS: 0.12935224175453186
# EPOCH 24 === BATCH: 4 === LOSS: 0.13148567080497742
# EPOCH 24 === BATCH: 5 === LOSS: 0.1346130669116974
# EPOCH 24 === BATCH: 6 === LOSS: 0.12880194187164307
# EPOCH 24 === BATCH: 7 === LOSS: 0.11761046946048737
# EPOCH 24 === BATCH: 8 === LOSS: 0.11751095950603485
# EPOCH 24 === BATCH: 9 === LOSS: 0.1330338418483734
# EPOCH 24 === BATCH: 10 === LOSS: 0.13775481283664703
# EPOCH 24 === BATCH: 11 === LOSS: 0.11584319919347763
# EPOCH 24 === BATCH: 12 === LOSS: 0.12921752035617828
# EPOCH 24 === BATCH: 13 === LOSS: 0.12195706367492676
# EPOCH 24 === BATCH: 14 === LOSS: 0.1304442584514618
# EPOCH 24 === BATCH: 15 === LOSS: 0.1148335188627243
# EPOCH 24 === BATCH: 16 === LOSS: 0.1331353783607483
# EPOCH 24 LOSS: 0.12537708366289735
# EPOCH 25 === BATCH: 1 === LOSS: 0.12588945031166077
# EPOCH 25 === BATCH: 2 === LOSS: 0.12269612401723862
# EPOCH 25 === BATCH: 3 === LOSS: 0.12489445507526398
# EPOCH 25 === BATCH: 4 === LOSS: 0.11546272039413452
# EPOCH 25 === BATCH: 5 === LOSS: 0.13011784851551056
# EPOCH 25 === BATCH: 6 === LOSS: 0.12580297887325287
# EPOCH 25 === BATCH: 7 === LOSS: 0.12387313693761826
# EPOCH 25 === BATCH: 8 === LOSS: 0.12046603858470917
# EPOCH 25 === BATCH: 9 === LOSS: 0.11827504634857178
# EPOCH 25 === BATCH: 10 === LOSS: 0.11553394794464111
# EPOCH 25 === BATCH: 11 === LOSS: 0.11760276556015015
# EPOCH 25 === BATCH: 12 === LOSS: 0.13825777173042297
# EPOCH 25 === BATCH: 13 === LOSS: 0.12295682728290558
# EPOCH 25 === BATCH: 14 === LOSS: 0.12754347920417786
# EPOCH 25 === BATCH: 15 === LOSS: 0.12472925335168839
# EPOCH 25 === BATCH: 16 === LOSS: 0.11512085795402527
# EPOCH 25 LOSS: 0.12307641888037324
# EPOCH 26 === BATCH: 1 === LOSS: 0.11520411819219589
# EPOCH 26 === BATCH: 2 === LOSS: 0.11253376305103302
# EPOCH 26 === BATCH: 3 === LOSS: 0.1183149591088295
# EPOCH 26 === BATCH: 4 === LOSS: 0.12090291827917099
# EPOCH 26 === BATCH: 5 === LOSS: 0.11495904624462128
# EPOCH 26 === BATCH: 6 === LOSS: 0.1165526956319809
# EPOCH 26 === BATCH: 7 === LOSS: 0.11777349561452866
# EPOCH 26 === BATCH: 8 === LOSS: 0.12387000024318695
# EPOCH 26 === BATCH: 9 === LOSS: 0.1270047128200531
# EPOCH 26 === BATCH: 10 === LOSS: 0.14676561951637268
# EPOCH 26 === BATCH: 11 === LOSS: 0.11638262122869492
# EPOCH 26 === BATCH: 12 === LOSS: 0.12322942912578583
# EPOCH 26 === BATCH: 13 === LOSS: 0.12413568794727325
# EPOCH 26 === BATCH: 14 === LOSS: 0.1301545947790146
# EPOCH 26 === BATCH: 15 === LOSS: 0.12758752703666687
# EPOCH 26 === BATCH: 16 === LOSS: 0.11570950597524643
# EPOCH 26 LOSS: 0.12194254342466593
# EPOCH 27 === BATCH: 1 === LOSS: 0.11358277499675751
# EPOCH 27 === BATCH: 2 === LOSS: 0.12115414440631866
# EPOCH 27 === BATCH: 3 === LOSS: 0.11986217647790909
# EPOCH 27 === BATCH: 4 === LOSS: 0.1149211972951889
# EPOCH 27 === BATCH: 5 === LOSS: 0.13102653622627258
# EPOCH 27 === BATCH: 6 === LOSS: 0.1272675096988678
# EPOCH 27 === BATCH: 7 === LOSS: 0.11780305206775665
# EPOCH 27 === BATCH: 8 === LOSS: 0.11543431133031845
# EPOCH 27 === BATCH: 9 === LOSS: 0.13627919554710388
# EPOCH 27 === BATCH: 10 === LOSS: 0.11620156466960907
# EPOCH 27 === BATCH: 11 === LOSS: 0.12265106290578842
# EPOCH 27 === BATCH: 12 === LOSS: 0.11965606361627579
# EPOCH 27 === BATCH: 13 === LOSS: 0.12964820861816406
# EPOCH 27 === BATCH: 14 === LOSS: 0.11231385171413422
# EPOCH 27 === BATCH: 15 === LOSS: 0.11090636253356934
# EPOCH 27 === BATCH: 16 === LOSS: 0.11351355910301208
# EPOCH 27 LOSS: 0.1201388482004404
# EPOCH 28 === BATCH: 1 === LOSS: 0.11920398473739624
# EPOCH 28 === BATCH: 2 === LOSS: 0.12914583086967468
# EPOCH 28 === BATCH: 3 === LOSS: 0.11358513683080673
# EPOCH 28 === BATCH: 4 === LOSS: 0.11840325593948364
# EPOCH 28 === BATCH: 5 === LOSS: 0.10362979024648666
# EPOCH 28 === BATCH: 6 === LOSS: 0.10922177881002426
# EPOCH 28 === BATCH: 7 === LOSS: 0.13636985421180725
# EPOCH 28 === BATCH: 8 === LOSS: 0.11940489709377289
# EPOCH 28 === BATCH: 9 === LOSS: 0.11849184334278107
# EPOCH 28 === BATCH: 10 === LOSS: 0.10948958247900009
# EPOCH 28 === BATCH: 11 === LOSS: 0.1141924113035202
# EPOCH 28 === BATCH: 12 === LOSS: 0.12802539765834808
# EPOCH 28 === BATCH: 13 === LOSS: 0.11648569256067276
# EPOCH 28 === BATCH: 14 === LOSS: 0.12060053646564484
# EPOCH 28 === BATCH: 15 === LOSS: 0.12578585743904114
# EPOCH 28 === BATCH: 16 === LOSS: 0.11428400874137878
# EPOCH 28 LOSS: 0.11851999117061496
# EPOCH 29 === BATCH: 1 === LOSS: 0.1066526398062706
# EPOCH 29 === BATCH: 2 === LOSS: 0.1175222173333168
# EPOCH 29 === BATCH: 3 === LOSS: 0.11976814270019531
# EPOCH 29 === BATCH: 4 === LOSS: 0.10624086856842041
# EPOCH 29 === BATCH: 5 === LOSS: 0.11554558575153351
# EPOCH 29 === BATCH: 6 === LOSS: 0.10372227430343628
# EPOCH 29 === BATCH: 7 === LOSS: 0.13248929381370544
# EPOCH 29 === BATCH: 8 === LOSS: 0.11801727861166
# EPOCH 29 === BATCH: 9 === LOSS: 0.1361992359161377
# EPOCH 29 === BATCH: 10 === LOSS: 0.11193408817052841
# EPOCH 29 === BATCH: 11 === LOSS: 0.10685521364212036
# EPOCH 29 === BATCH: 12 === LOSS: 0.12238204479217529
# EPOCH 29 === BATCH: 13 === LOSS: 0.12677323818206787
# EPOCH 29 === BATCH: 14 === LOSS: 0.12175653874874115
# EPOCH 29 === BATCH: 15 === LOSS: 0.10450734198093414
# EPOCH 29 === BATCH: 16 === LOSS: 0.13093362748622894
# EPOCH 29 LOSS: 0.11758122686296701
# EPOCH 30 === BATCH: 1 === LOSS: 0.10731301456689835
# EPOCH 30 === BATCH: 2 === LOSS: 0.12043480575084686
# EPOCH 30 === BATCH: 3 === LOSS: 0.11629684269428253
# EPOCH 30 === BATCH: 4 === LOSS: 0.11734811961650848
# EPOCH 30 === BATCH: 5 === LOSS: 0.1223011165857315
# EPOCH 30 === BATCH: 6 === LOSS: 0.12076258659362793
# EPOCH 30 === BATCH: 7 === LOSS: 0.10378386825323105
# EPOCH 30 === BATCH: 8 === LOSS: 0.10909311473369598
# EPOCH 30 === BATCH: 9 === LOSS: 0.09787236154079437
# EPOCH 30 === BATCH: 10 === LOSS: 0.12088348716497421
# EPOCH 30 === BATCH: 11 === LOSS: 0.11552800238132477
# EPOCH 30 === BATCH: 12 === LOSS: 0.12519273161888123
# EPOCH 30 === BATCH: 13 === LOSS: 0.1295027881860733
# EPOCH 30 === BATCH: 14 === LOSS: 0.11629877239465714
# EPOCH 30 === BATCH: 15 === LOSS: 0.11123526096343994
# EPOCH 30 === BATCH: 16 === LOSS: 0.11795787513256073
# EPOCH 30 LOSS: 0.11573779676109552
# EPOCH 31 === BATCH: 1 === LOSS: 0.11028923094272614
# EPOCH 31 === BATCH: 2 === LOSS: 0.09973253309726715
# EPOCH 31 === BATCH: 3 === LOSS: 0.10704592615365982
# EPOCH 31 === BATCH: 4 === LOSS: 0.10805553197860718
# EPOCH 31 === BATCH: 5 === LOSS: 0.11810247600078583
# EPOCH 31 === BATCH: 6 === LOSS: 0.12450864166021347
# EPOCH 31 === BATCH: 7 === LOSS: 0.11813155561685562
# EPOCH 31 === BATCH: 8 === LOSS: 0.12233219295740128
# EPOCH 31 === BATCH: 9 === LOSS: 0.10781797021627426
# EPOCH 31 === BATCH: 10 === LOSS: 0.11927914619445801
# EPOCH 31 === BATCH: 11 === LOSS: 0.12812539935112
# EPOCH 31 === BATCH: 12 === LOSS: 0.11494854837656021
# EPOCH 31 === BATCH: 13 === LOSS: 0.12810645997524261
# EPOCH 31 === BATCH: 14 === LOSS: 0.1032523512840271
# EPOCH 31 === BATCH: 15 === LOSS: 0.1066424623131752
# EPOCH 31 === BATCH: 16 === LOSS: 0.11183763295412064
# EPOCH 31 LOSS: 0.1142630036920309
# EPOCH 32 === BATCH: 1 === LOSS: 0.10881362855434418
# EPOCH 32 === BATCH: 2 === LOSS: 0.11701767146587372
# EPOCH 32 === BATCH: 3 === LOSS: 0.11616379022598267
# EPOCH 32 === BATCH: 4 === LOSS: 0.10770283639431
# EPOCH 32 === BATCH: 5 === LOSS: 0.11215221881866455
# EPOCH 32 === BATCH: 6 === LOSS: 0.11850645393133163
# EPOCH 32 === BATCH: 7 === LOSS: 0.11881951987743378
# EPOCH 32 === BATCH: 8 === LOSS: 0.11906717717647552
# EPOCH 32 === BATCH: 9 === LOSS: 0.10550494492053986
# EPOCH 32 === BATCH: 10 === LOSS: 0.12050209194421768
# EPOCH 32 === BATCH: 11 === LOSS: 0.1157776340842247
# EPOCH 32 === BATCH: 12 === LOSS: 0.11242304742336273
# EPOCH 32 === BATCH: 13 === LOSS: 0.11361609399318695
# EPOCH 32 === BATCH: 14 === LOSS: 0.0906129851937294
# EPOCH 32 === BATCH: 15 === LOSS: 0.11522646993398666
# EPOCH 32 === BATCH: 16 === LOSS: 0.12339747697114944
# EPOCH 32 LOSS: 0.11345650255680084
# EPOCH 33 === BATCH: 1 === LOSS: 0.10488716512918472
# EPOCH 33 === BATCH: 2 === LOSS: 0.13361729681491852
# EPOCH 33 === BATCH: 3 === LOSS: 0.125515416264534
# EPOCH 33 === BATCH: 4 === LOSS: 0.10985350608825684
# EPOCH 33 === BATCH: 5 === LOSS: 0.09949763119220734
# EPOCH 33 === BATCH: 6 === LOSS: 0.10804367065429688
# EPOCH 33 === BATCH: 7 === LOSS: 0.09589243680238724
# EPOCH 33 === BATCH: 8 === LOSS: 0.11268573999404907
# EPOCH 33 === BATCH: 9 === LOSS: 0.11502264440059662
# EPOCH 33 === BATCH: 10 === LOSS: 0.10547347366809845
# EPOCH 33 === BATCH: 11 === LOSS: 0.12134180963039398
# EPOCH 33 === BATCH: 12 === LOSS: 0.11930765956640244
# EPOCH 33 === BATCH: 13 === LOSS: 0.10578471422195435
# EPOCH 33 === BATCH: 14 === LOSS: 0.11624151468276978
# EPOCH 33 === BATCH: 15 === LOSS: 0.1100960224866867
# EPOCH 33 === BATCH: 16 === LOSS: 0.11136414855718613
# EPOCH 33 LOSS: 0.11216405313462019
# EPOCH 34 === BATCH: 1 === LOSS: 0.11236782371997833
# EPOCH 34 === BATCH: 2 === LOSS: 0.1311507225036621
# EPOCH 34 === BATCH: 3 === LOSS: 0.09959165751934052
# EPOCH 34 === BATCH: 4 === LOSS: 0.1316029131412506
# EPOCH 34 === BATCH: 5 === LOSS: 0.09835778176784515
# EPOCH 34 === BATCH: 6 === LOSS: 0.11327947676181793
# EPOCH 34 === BATCH: 7 === LOSS: 0.10227420181035995
# EPOCH 34 === BATCH: 8 === LOSS: 0.10353543609380722
# EPOCH 34 === BATCH: 9 === LOSS: 0.1118326336145401
# EPOCH 34 === BATCH: 10 === LOSS: 0.1114419549703598
# EPOCH 34 === BATCH: 11 === LOSS: 0.09729848802089691
# EPOCH 34 === BATCH: 12 === LOSS: 0.11846635490655899
# EPOCH 34 === BATCH: 13 === LOSS: 0.10343761742115021
# EPOCH 34 === BATCH: 14 === LOSS: 0.11613766849040985
# EPOCH 34 === BATCH: 15 === LOSS: 0.11165447533130646
# EPOCH 34 === BATCH: 16 === LOSS: 0.1019614189863205
# EPOCH 34 LOSS: 0.11027441406622529
# EPOCH 35 === BATCH: 1 === LOSS: 0.10361091792583466
# EPOCH 35 === BATCH: 2 === LOSS: 0.09335722774267197
# EPOCH 35 === BATCH: 3 === LOSS: 0.10093635320663452
# EPOCH 35 === BATCH: 4 === LOSS: 0.10843078047037125
# EPOCH 35 === BATCH: 5 === LOSS: 0.1274031102657318
# EPOCH 35 === BATCH: 6 === LOSS: 0.08906561136245728
# EPOCH 35 === BATCH: 7 === LOSS: 0.1162790060043335
# EPOCH 35 === BATCH: 8 === LOSS: 0.10855530202388763
# EPOCH 35 === BATCH: 9 === LOSS: 0.12202426046133041
# EPOCH 35 === BATCH: 10 === LOSS: 0.10362901538610458
# EPOCH 35 === BATCH: 11 === LOSS: 0.11302490532398224
# EPOCH 35 === BATCH: 12 === LOSS: 0.11624342203140259
# EPOCH 35 === BATCH: 13 === LOSS: 0.11687266826629639
# EPOCH 35 === BATCH: 14 === LOSS: 0.12211056798696518
# EPOCH 35 === BATCH: 15 === LOSS: 0.10976231098175049
# EPOCH 35 === BATCH: 16 === LOSS: 0.10329680144786835
# EPOCH 35 LOSS: 0.10966264130547643
# EPOCH 36 === BATCH: 1 === LOSS: 0.12763284146785736
# EPOCH 36 === BATCH: 2 === LOSS: 0.11526358127593994
# EPOCH 36 === BATCH: 3 === LOSS: 0.0957367941737175
# EPOCH 36 === BATCH: 4 === LOSS: 0.09922252595424652
# EPOCH 36 === BATCH: 5 === LOSS: 0.10569970309734344
# EPOCH 36 === BATCH: 6 === LOSS: 0.11617952585220337
# EPOCH 36 === BATCH: 7 === LOSS: 0.10346359014511108
# EPOCH 36 === BATCH: 8 === LOSS: 0.1033693179488182
# EPOCH 36 === BATCH: 9 === LOSS: 0.1085072010755539
# EPOCH 36 === BATCH: 10 === LOSS: 0.09612240642309189
# EPOCH 36 === BATCH: 11 === LOSS: 0.10981829464435577
# EPOCH 36 === BATCH: 12 === LOSS: 0.11585333198308945
# EPOCH 36 === BATCH: 13 === LOSS: 0.08902418613433838
# EPOCH 36 === BATCH: 14 === LOSS: 0.11983052641153336
# EPOCH 36 === BATCH: 15 === LOSS: 0.12151358276605606
# EPOCH 36 === BATCH: 16 === LOSS: 0.11710568517446518
# EPOCH 36 LOSS: 0.10902144340798259
# EPOCH 37 === BATCH: 1 === LOSS: 0.08959793299436569
# EPOCH 37 === BATCH: 2 === LOSS: 0.09680482000112534
# EPOCH 37 === BATCH: 3 === LOSS: 0.11831612884998322
# EPOCH 37 === BATCH: 4 === LOSS: 0.10516134649515152
# EPOCH 37 === BATCH: 5 === LOSS: 0.10246877372264862
# EPOCH 37 === BATCH: 6 === LOSS: 0.11257042735815048
# EPOCH 37 === BATCH: 7 === LOSS: 0.12255390733480453
# EPOCH 37 === BATCH: 8 === LOSS: 0.128690704703331
# EPOCH 37 === BATCH: 9 === LOSS: 0.10110070556402206
# EPOCH 37 === BATCH: 10 === LOSS: 0.10249656438827515
# EPOCH 37 === BATCH: 11 === LOSS: 0.10788954794406891
# EPOCH 37 === BATCH: 12 === LOSS: 0.11407484859228134
# EPOCH 37 === BATCH: 13 === LOSS: 0.10400339215993881
# EPOCH 37 === BATCH: 14 === LOSS: 0.10277452319860458
# EPOCH 37 === BATCH: 15 === LOSS: 0.10476124286651611
# EPOCH 37 === BATCH: 16 === LOSS: 0.11607717722654343
# EPOCH 37 LOSS: 0.10808387771248817
# EPOCH 38 === BATCH: 1 === LOSS: 0.10908423364162445
# EPOCH 38 === BATCH: 2 === LOSS: 0.1221478134393692
# EPOCH 38 === BATCH: 3 === LOSS: 0.1156713217496872
# EPOCH 38 === BATCH: 4 === LOSS: 0.09369497001171112
# EPOCH 38 === BATCH: 5 === LOSS: 0.0900496393442154
# EPOCH 38 === BATCH: 6 === LOSS: 0.12365231662988663
# EPOCH 38 === BATCH: 7 === LOSS: 0.10937251895666122
# EPOCH 38 === BATCH: 8 === LOSS: 0.10204198211431503
# EPOCH 38 === BATCH: 9 === LOSS: 0.10419608652591705
# EPOCH 38 === BATCH: 10 === LOSS: 0.10956505686044693
# EPOCH 38 === BATCH: 11 === LOSS: 0.10059241205453873
# EPOCH 38 === BATCH: 12 === LOSS: 0.11430822312831879
# EPOCH 38 === BATCH: 13 === LOSS: 0.10855463892221451
# EPOCH 38 === BATCH: 14 === LOSS: 0.09774205088615417
# EPOCH 38 === BATCH: 15 === LOSS: 0.09835214912891388
# EPOCH 38 === BATCH: 16 === LOSS: 0.100092813372612
# EPOCH 38 LOSS: 0.10619488917291164
# EPOCH 39 === BATCH: 1 === LOSS: 0.10422512143850327
# EPOCH 39 === BATCH: 2 === LOSS: 0.10880676656961441
# EPOCH 39 === BATCH: 3 === LOSS: 0.09108464419841766
# EPOCH 39 === BATCH: 4 === LOSS: 0.11819694191217422
# EPOCH 39 === BATCH: 5 === LOSS: 0.0937517061829567
# EPOCH 39 === BATCH: 6 === LOSS: 0.09985525906085968
# EPOCH 39 === BATCH: 7 === LOSS: 0.11125047504901886
# EPOCH 39 === BATCH: 8 === LOSS: 0.09975583851337433
# EPOCH 39 === BATCH: 9 === LOSS: 0.10435229539871216
# EPOCH 39 === BATCH: 10 === LOSS: 0.10113736242055893
# EPOCH 39 === BATCH: 11 === LOSS: 0.11345990747213364
# EPOCH 39 === BATCH: 12 === LOSS: 0.1120474562048912
# EPOCH 39 === BATCH: 13 === LOSS: 0.09737923741340637
# EPOCH 39 === BATCH: 14 === LOSS: 0.10799473524093628
# EPOCH 39 === BATCH: 15 === LOSS: 0.10930854082107544
# EPOCH 39 === BATCH: 16 === LOSS: 0.11865217238664627
# EPOCH 39 LOSS: 0.10570365376770496
# EPOCH 40 === BATCH: 1 === LOSS: 0.10950825363397598
# EPOCH 40 === BATCH: 2 === LOSS: 0.1038324385881424
# EPOCH 40 === BATCH: 3 === LOSS: 0.0998353511095047
# EPOCH 40 === BATCH: 4 === LOSS: 0.10418559610843658
# EPOCH 40 === BATCH: 5 === LOSS: 0.11628526449203491
# EPOCH 40 === BATCH: 6 === LOSS: 0.11060263216495514
# EPOCH 40 === BATCH: 7 === LOSS: 0.10867830365896225
# EPOCH 40 === BATCH: 8 === LOSS: 0.09925399720668793
# EPOCH 40 === BATCH: 9 === LOSS: 0.11510641872882843
# EPOCH 40 === BATCH: 10 === LOSS: 0.1090480238199234
# EPOCH 40 === BATCH: 11 === LOSS: 0.0984138622879982
# EPOCH 40 === BATCH: 12 === LOSS: 0.09390205889940262
# EPOCH 40 === BATCH: 13 === LOSS: 0.10095609724521637
# EPOCH 40 === BATCH: 14 === LOSS: 0.07968340814113617
# EPOCH 40 === BATCH: 15 === LOSS: 0.11359035968780518
# EPOCH 40 === BATCH: 16 === LOSS: 0.10673829913139343
# EPOCH 40 LOSS: 0.10435127280652523
# EPOCH 41 === BATCH: 1 === LOSS: 0.10169677436351776
# EPOCH 41 === BATCH: 2 === LOSS: 0.10334043204784393
# EPOCH 41 === BATCH: 3 === LOSS: 0.10248424857854843
# EPOCH 41 === BATCH: 4 === LOSS: 0.0971875712275505
# EPOCH 41 === BATCH: 5 === LOSS: 0.09511496126651764
# EPOCH 41 === BATCH: 6 === LOSS: 0.11257968097925186
# EPOCH 41 === BATCH: 7 === LOSS: 0.10471267998218536
# EPOCH 41 === BATCH: 8 === LOSS: 0.09882278740406036
# EPOCH 41 === BATCH: 9 === LOSS: 0.10424582660198212
# EPOCH 41 === BATCH: 10 === LOSS: 0.1030815988779068
# EPOCH 41 === BATCH: 11 === LOSS: 0.11383016407489777
# EPOCH 41 === BATCH: 12 === LOSS: 0.1095631867647171
# EPOCH 41 === BATCH: 13 === LOSS: 0.10810984671115875
# EPOCH 41 === BATCH: 14 === LOSS: 0.10021648555994034
# EPOCH 41 === BATCH: 15 === LOSS: 0.10654313862323761
# EPOCH 41 === BATCH: 16 === LOSS: 0.09173107147216797
# EPOCH 41 LOSS: 0.10332877840846777
# EPOCH 42 === BATCH: 1 === LOSS: 0.09603475034236908
# EPOCH 42 === BATCH: 2 === LOSS: 0.08779091387987137
# EPOCH 42 === BATCH: 3 === LOSS: 0.10053537786006927
# EPOCH 42 === BATCH: 4 === LOSS: 0.12043578922748566
# EPOCH 42 === BATCH: 5 === LOSS: 0.1082027405500412
# EPOCH 42 === BATCH: 6 === LOSS: 0.09074754267930984
# EPOCH 42 === BATCH: 7 === LOSS: 0.12089475244283676
# EPOCH 42 === BATCH: 8 === LOSS: 0.09382021427154541
# EPOCH 42 === BATCH: 9 === LOSS: 0.09235822409391403
# EPOCH 42 === BATCH: 10 === LOSS: 0.10085548460483551
# EPOCH 42 === BATCH: 11 === LOSS: 0.10251740366220474
# EPOCH 42 === BATCH: 12 === LOSS: 0.11202101409435272
# EPOCH 42 === BATCH: 13 === LOSS: 0.09746651351451874
# EPOCH 42 === BATCH: 14 === LOSS: 0.11444962024688721
# EPOCH 42 === BATCH: 15 === LOSS: 0.11033059656620026
# EPOCH 42 === BATCH: 16 === LOSS: 0.08330440521240234
# EPOCH 42 LOSS: 0.10198533395305276
# EPOCH 43 === BATCH: 1 === LOSS: 0.09806926548480988
# EPOCH 43 === BATCH: 2 === LOSS: 0.10513199865818024
# EPOCH 43 === BATCH: 3 === LOSS: 0.10410626232624054
# EPOCH 43 === BATCH: 4 === LOSS: 0.10117076337337494
# EPOCH 43 === BATCH: 5 === LOSS: 0.10410330444574356
# EPOCH 43 === BATCH: 6 === LOSS: 0.10879591852426529
# EPOCH 43 === BATCH: 7 === LOSS: 0.09754811227321625
# EPOCH 43 === BATCH: 8 === LOSS: 0.10372450202703476
# EPOCH 43 === BATCH: 9 === LOSS: 0.08548583835363388
# EPOCH 43 === BATCH: 10 === LOSS: 0.09918481856584549
# EPOCH 43 === BATCH: 11 === LOSS: 0.11182285845279694
# EPOCH 43 === BATCH: 12 === LOSS: 0.09483953565359116
# EPOCH 43 === BATCH: 13 === LOSS: 0.10634738206863403
# EPOCH 43 === BATCH: 14 === LOSS: 0.10685165971517563
# EPOCH 43 === BATCH: 15 === LOSS: 0.1021580919623375
# EPOCH 43 === BATCH: 16 === LOSS: 0.09777013957500458
# EPOCH 43 LOSS: 0.10169440321624279
# EPOCH 44 === BATCH: 1 === LOSS: 0.11321821063756943
# EPOCH 44 === BATCH: 2 === LOSS: 0.10459767282009125
# EPOCH 44 === BATCH: 3 === LOSS: 0.11715450137853622
# EPOCH 44 === BATCH: 4 === LOSS: 0.1063527837395668
# EPOCH 44 === BATCH: 5 === LOSS: 0.10859539359807968
# EPOCH 44 === BATCH: 6 === LOSS: 0.09228835254907608
# EPOCH 44 === BATCH: 7 === LOSS: 0.08923784643411636
# EPOCH 44 === BATCH: 8 === LOSS: 0.09599627554416656
# EPOCH 44 === BATCH: 9 === LOSS: 0.10817066580057144
# EPOCH 44 === BATCH: 10 === LOSS: 0.0979771837592125
# EPOCH 44 === BATCH: 11 === LOSS: 0.09528671950101852
# EPOCH 44 === BATCH: 12 === LOSS: 0.09136617928743362
# EPOCH 44 === BATCH: 13 === LOSS: 0.08745650202035904
# EPOCH 44 === BATCH: 14 === LOSS: 0.08056134730577469
# EPOCH 44 === BATCH: 15 === LOSS: 0.11822724342346191
# EPOCH 44 === BATCH: 16 === LOSS: 0.11863262206315994
# EPOCH 44 LOSS: 0.10156996874138713
# EPOCH 45 === BATCH: 1 === LOSS: 0.0848485603928566
# EPOCH 45 === BATCH: 2 === LOSS: 0.11730705201625824
# EPOCH 45 === BATCH: 3 === LOSS: 0.09619615226984024
# EPOCH 45 === BATCH: 4 === LOSS: 0.09553269296884537
# EPOCH 45 === BATCH: 5 === LOSS: 0.09245765954256058
# EPOCH 45 === BATCH: 6 === LOSS: 0.11338184773921967
# EPOCH 45 === BATCH: 7 === LOSS: 0.0734635591506958
# EPOCH 45 === BATCH: 8 === LOSS: 0.08670277893543243
# EPOCH 45 === BATCH: 9 === LOSS: 0.09221218526363373
# EPOCH 45 === BATCH: 10 === LOSS: 0.11562982946634293
# EPOCH 45 === BATCH: 11 === LOSS: 0.09591370820999146
# EPOCH 45 === BATCH: 12 === LOSS: 0.10737444460391998
# EPOCH 45 === BATCH: 13 === LOSS: 0.10622318089008331
# EPOCH 45 === BATCH: 14 === LOSS: 0.0994078740477562
# EPOCH 45 === BATCH: 15 === LOSS: 0.10509943962097168
# EPOCH 45 === BATCH: 16 === LOSS: 0.1274726837873459
# EPOCH 45 LOSS: 0.10057647805660963
# EPOCH 46 === BATCH: 1 === LOSS: 0.08594561368227005
# EPOCH 46 === BATCH: 2 === LOSS: 0.10339375585317612
# EPOCH 46 === BATCH: 3 === LOSS: 0.09399765729904175
# EPOCH 46 === BATCH: 4 === LOSS: 0.11606357991695404
# EPOCH 46 === BATCH: 5 === LOSS: 0.10681015253067017
# EPOCH 46 === BATCH: 6 === LOSS: 0.11008340120315552
# EPOCH 46 === BATCH: 7 === LOSS: 0.09072060883045197
# EPOCH 46 === BATCH: 8 === LOSS: 0.09740760922431946
# EPOCH 46 === BATCH: 9 === LOSS: 0.08851775527000427
# EPOCH 46 === BATCH: 10 === LOSS: 0.09770023077726364
# EPOCH 46 === BATCH: 11 === LOSS: 0.11736919730901718
# EPOCH 46 === BATCH: 12 === LOSS: 0.09363213926553726
# EPOCH 46 === BATCH: 13 === LOSS: 0.08772629499435425
# EPOCH 46 === BATCH: 14 === LOSS: 0.10063330829143524
# EPOCH 46 === BATCH: 15 === LOSS: 0.09852106869220734
# EPOCH 46 === BATCH: 16 === LOSS: 0.09636988490819931
# EPOCH 46 LOSS: 0.0990557661280036
# EPOCH 47 === BATCH: 1 === LOSS: 0.09466828405857086
# EPOCH 47 === BATCH: 2 === LOSS: 0.09454494714736938
# EPOCH 47 === BATCH: 3 === LOSS: 0.0900120884180069
# EPOCH 47 === BATCH: 4 === LOSS: 0.10764557123184204
# EPOCH 47 === BATCH: 5 === LOSS: 0.09593473374843597
# EPOCH 47 === BATCH: 6 === LOSS: 0.09401911497116089
# EPOCH 47 === BATCH: 7 === LOSS: 0.1063922643661499
# EPOCH 47 === BATCH: 8 === LOSS: 0.10257260501384735
# EPOCH 47 === BATCH: 9 === LOSS: 0.10547902435064316
# EPOCH 47 === BATCH: 10 === LOSS: 0.10630415380001068
# EPOCH 47 === BATCH: 11 === LOSS: 0.10984492301940918
# EPOCH 47 === BATCH: 12 === LOSS: 0.08774331957101822
# EPOCH 47 === BATCH: 13 === LOSS: 0.11377237737178802
# EPOCH 47 === BATCH: 14 === LOSS: 0.08129516988992691
# EPOCH 47 === BATCH: 15 === LOSS: 0.1066974401473999
# EPOCH 47 === BATCH: 16 === LOSS: 0.07249702513217926
# EPOCH 47 LOSS: 0.09808894013985991
# EPOCH 48 === BATCH: 1 === LOSS: 0.09446022659540176
# EPOCH 48 === BATCH: 2 === LOSS: 0.10282975435256958
# EPOCH 48 === BATCH: 3 === LOSS: 0.09262391924858093
# EPOCH 48 === BATCH: 4 === LOSS: 0.09521247446537018
# EPOCH 48 === BATCH: 5 === LOSS: 0.08648619055747986
# EPOCH 48 === BATCH: 6 === LOSS: 0.11002032458782196
# EPOCH 48 === BATCH: 7 === LOSS: 0.10822583734989166
# EPOCH 48 === BATCH: 8 === LOSS: 0.09894796460866928
# EPOCH 48 === BATCH: 9 === LOSS: 0.09023131430149078
# EPOCH 48 === BATCH: 10 === LOSS: 0.09146874397993088
# EPOCH 48 === BATCH: 11 === LOSS: 0.09239594638347626
# EPOCH 48 === BATCH: 12 === LOSS: 0.11335299909114838
# EPOCH 48 === BATCH: 13 === LOSS: 0.10748602449893951
# EPOCH 48 === BATCH: 14 === LOSS: 0.08601921796798706
# EPOCH 48 === BATCH: 15 === LOSS: 0.10818089544773102
# EPOCH 48 === BATCH: 16 === LOSS: 0.07432657480239868
# EPOCH 48 LOSS: 0.09701677551493049
# EPOCH 49 === BATCH: 1 === LOSS: 0.10447846353054047
# EPOCH 49 === BATCH: 2 === LOSS: 0.08691587299108505
# EPOCH 49 === BATCH: 3 === LOSS: 0.08588536083698273
# EPOCH 49 === BATCH: 4 === LOSS: 0.09913502633571625
# EPOCH 49 === BATCH: 5 === LOSS: 0.10022424161434174
# EPOCH 49 === BATCH: 6 === LOSS: 0.10076989978551865
# EPOCH 49 === BATCH: 7 === LOSS: 0.10664507001638412
# EPOCH 49 === BATCH: 8 === LOSS: 0.1111329048871994
# EPOCH 49 === BATCH: 9 === LOSS: 0.09815935790538788
# EPOCH 49 === BATCH: 10 === LOSS: 0.08682184666395187
# EPOCH 49 === BATCH: 11 === LOSS: 0.07391463965177536
# EPOCH 49 === BATCH: 12 === LOSS: 0.0897703543305397
# EPOCH 49 === BATCH: 13 === LOSS: 0.10835017263889313
# EPOCH 49 === BATCH: 14 === LOSS: 0.0973840057849884
# EPOCH 49 === BATCH: 15 === LOSS: 0.10206514596939087
# EPOCH 49 === BATCH: 16 === LOSS: 0.09980130940675735
# EPOCH 49 LOSS: 0.09696585452184081
# EPOCH 50 === BATCH: 1 === LOSS: 0.08863545954227448
# EPOCH 50 === BATCH: 2 === LOSS: 0.0942784994840622
# EPOCH 50 === BATCH: 3 === LOSS: 0.09257005155086517
# EPOCH 50 === BATCH: 4 === LOSS: 0.10531065613031387
# EPOCH 50 === BATCH: 5 === LOSS: 0.09552016109228134
# EPOCH 50 === BATCH: 6 === LOSS: 0.0953509584069252
# EPOCH 50 === BATCH: 7 === LOSS: 0.10074305534362793
# EPOCH 50 === BATCH: 8 === LOSS: 0.08614859730005264
# EPOCH 50 === BATCH: 9 === LOSS: 0.08947550505399704
# EPOCH 50 === BATCH: 10 === LOSS: 0.10577784478664398
# EPOCH 50 === BATCH: 11 === LOSS: 0.098356232047081
# EPOCH 50 === BATCH: 12 === LOSS: 0.10299189388751984
# EPOCH 50 === BATCH: 13 === LOSS: 0.1002681627869606
# EPOCH 50 === BATCH: 14 === LOSS: 0.09665267169475555
# EPOCH 50 === BATCH: 15 === LOSS: 0.08316313475370407
# EPOCH 50 === BATCH: 16 === LOSS: 0.10927581787109375
# EPOCH 50 LOSS: 0.09653241885825992
# EPOCH 51 === BATCH: 1 === LOSS: 0.10144944489002228
# EPOCH 51 === BATCH: 2 === LOSS: 0.09828425943851471
# EPOCH 51 === BATCH: 3 === LOSS: 0.0947624146938324
# EPOCH 51 === BATCH: 4 === LOSS: 0.08272938430309296
# EPOCH 51 === BATCH: 5 === LOSS: 0.08346433937549591
# EPOCH 51 === BATCH: 6 === LOSS: 0.09436601400375366
# EPOCH 51 === BATCH: 7 === LOSS: 0.10250644385814667
# EPOCH 51 === BATCH: 8 === LOSS: 0.09352238476276398
# EPOCH 51 === BATCH: 9 === LOSS: 0.0884094089269638
# EPOCH 51 === BATCH: 10 === LOSS: 0.10326371341943741
# EPOCH 51 === BATCH: 11 === LOSS: 0.08936754614114761
# EPOCH 51 === BATCH: 12 === LOSS: 0.1264597773551941
# EPOCH 51 === BATCH: 13 === LOSS: 0.09327047318220139
# EPOCH 51 === BATCH: 14 === LOSS: 0.08578269183635712
# EPOCH 51 === BATCH: 15 === LOSS: 0.10192539542913437
# EPOCH 51 === BATCH: 16 === LOSS: 0.0907285138964653
# EPOCH 51 LOSS: 0.09564326284453273
# EPOCH 52 === BATCH: 1 === LOSS: 0.09093586355447769
# EPOCH 52 === BATCH: 2 === LOSS: 0.09365803003311157
# EPOCH 52 === BATCH: 3 === LOSS: 0.09090851247310638
# EPOCH 52 === BATCH: 4 === LOSS: 0.08898596465587616
# EPOCH 52 === BATCH: 5 === LOSS: 0.09087041020393372
# EPOCH 52 === BATCH: 6 === LOSS: 0.09601756185293198
# EPOCH 52 === BATCH: 7 === LOSS: 0.09184776991605759
# EPOCH 52 === BATCH: 8 === LOSS: 0.0921984389424324
# EPOCH 52 === BATCH: 9 === LOSS: 0.09934841096401215
# EPOCH 52 === BATCH: 10 === LOSS: 0.10400988906621933
# EPOCH 52 === BATCH: 11 === LOSS: 0.06775154173374176
# EPOCH 52 === BATCH: 12 === LOSS: 0.10781464725732803
# EPOCH 52 === BATCH: 13 === LOSS: 0.1051650270819664
# EPOCH 52 === BATCH: 14 === LOSS: 0.10419837385416031
# EPOCH 52 === BATCH: 15 === LOSS: 0.10460281372070312
# EPOCH 52 === BATCH: 16 === LOSS: 0.09523677080869675
# EPOCH 52 LOSS: 0.09522187663242221
# EPOCH 53 === BATCH: 1 === LOSS: 0.092725470662117
# EPOCH 53 === BATCH: 2 === LOSS: 0.09621217101812363
# EPOCH 53 === BATCH: 3 === LOSS: 0.1001087874174118
# EPOCH 53 === BATCH: 4 === LOSS: 0.10253529250621796
# EPOCH 53 === BATCH: 5 === LOSS: 0.09423701465129852
# EPOCH 53 === BATCH: 6 === LOSS: 0.10307679325342178
# EPOCH 53 === BATCH: 7 === LOSS: 0.10117568075656891
# EPOCH 53 === BATCH: 8 === LOSS: 0.08207210898399353
# EPOCH 53 === BATCH: 9 === LOSS: 0.10015060752630234
# EPOCH 53 === BATCH: 10 === LOSS: 0.07883448898792267
# EPOCH 53 === BATCH: 11 === LOSS: 0.09823764115571976
# EPOCH 53 === BATCH: 12 === LOSS: 0.08591076731681824
# EPOCH 53 === BATCH: 13 === LOSS: 0.08963223546743393
# EPOCH 53 === BATCH: 14 === LOSS: 0.10196970403194427
# EPOCH 53 === BATCH: 15 === LOSS: 0.10011366754770279
# EPOCH 53 === BATCH: 16 === LOSS: 0.07575810700654984
# EPOCH 53 LOSS: 0.09392190864309669
# EPOCH 54 === BATCH: 1 === LOSS: 0.09783055633306503
# EPOCH 54 === BATCH: 2 === LOSS: 0.09603877365589142
# EPOCH 54 === BATCH: 3 === LOSS: 0.09444217383861542
# EPOCH 54 === BATCH: 4 === LOSS: 0.09250377118587494
# EPOCH 54 === BATCH: 5 === LOSS: 0.09211080521345139
# EPOCH 54 === BATCH: 6 === LOSS: 0.08101852238178253
# EPOCH 54 === BATCH: 7 === LOSS: 0.09299027919769287
# EPOCH 54 === BATCH: 8 === LOSS: 0.11031915247440338
# EPOCH 54 === BATCH: 9 === LOSS: 0.08753359317779541
# EPOCH 54 === BATCH: 10 === LOSS: 0.09979590773582458
# EPOCH 54 === BATCH: 11 === LOSS: 0.08039578050374985
# EPOCH 54 === BATCH: 12 === LOSS: 0.10330145061016083
# EPOCH 54 === BATCH: 13 === LOSS: 0.09465213119983673
# EPOCH 54 === BATCH: 14 === LOSS: 0.09616987407207489
# EPOCH 54 === BATCH: 15 === LOSS: 0.07967525720596313
# EPOCH 54 === BATCH: 16 === LOSS: 0.10091572999954224
# EPOCH 54 LOSS: 0.09373085992410779
# EPOCH 55 === BATCH: 1 === LOSS: 0.10247974097728729
# EPOCH 55 === BATCH: 2 === LOSS: 0.09812276065349579
# EPOCH 55 === BATCH: 3 === LOSS: 0.0995558425784111
# EPOCH 55 === BATCH: 4 === LOSS: 0.08483590185642242
# EPOCH 55 === BATCH: 5 === LOSS: 0.10628149658441544
# EPOCH 55 === BATCH: 6 === LOSS: 0.0860665962100029
# EPOCH 55 === BATCH: 7 === LOSS: 0.09474491328001022
# EPOCH 55 === BATCH: 8 === LOSS: 0.09258212149143219
# EPOCH 55 === BATCH: 9 === LOSS: 0.08911825716495514
# EPOCH 55 === BATCH: 10 === LOSS: 0.09104601293802261
# EPOCH 55 === BATCH: 11 === LOSS: 0.10128279030323029
# EPOCH 55 === BATCH: 12 === LOSS: 0.09468604624271393
# EPOCH 55 === BATCH: 13 === LOSS: 0.08592969179153442
# EPOCH 55 === BATCH: 14 === LOSS: 0.08806595206260681
# EPOCH 55 === BATCH: 15 === LOSS: 0.08145678043365479
# EPOCH 55 === BATCH: 16 === LOSS: 0.0840827003121376
# EPOCH 55 LOSS: 0.09252110030502081
# EPOCH 56 === BATCH: 1 === LOSS: 0.09039478003978729
# EPOCH 56 === BATCH: 2 === LOSS: 0.10502646118402481
# EPOCH 56 === BATCH: 3 === LOSS: 0.09109460562467575
# EPOCH 56 === BATCH: 4 === LOSS: 0.09656156599521637
# EPOCH 56 === BATCH: 5 === LOSS: 0.06978534162044525
# ...
# EPOCH 483 === BATCH: 6 === LOSS: 0.009967687539756298
# EPOCH 483 === BATCH: 7 === LOSS: 0.03546743839979172
# EPOCH 483 === BATCH: 8 === LOSS: 0.00964166410267353
# EPOCH 483 === BATCH: 9 === LOSS: 0.008760331198573112
# EPOCH 483 === BATCH: 10 === LOSS: 0.009347537532448769
# EPOCH 483 === BATCH: 11 === LOSS: 0.019202174618840218
# EPOCH 483 === BATCH: 12 === LOSS: 0.004461892414838076
# EPOCH 483 === BATCH: 13 === LOSS: 0.009803785011172295
# EPOCH 483 === BATCH: 14 === LOSS: 0.03289083391427994
# EPOCH 483 === BATCH: 15 === LOSS: 0.0350366048514843
# EPOCH 483 === BATCH: 16 === LOSS: 0.016159771010279655
# EPOCH 483 LOSS: 0.017456452565966174
# EPOCH 484 === BATCH: 1 === LOSS: 0.020526375621557236
# EPOCH 484 === BATCH: 2 === LOSS: 0.006814241409301758
# EPOCH 484 === BATCH: 3 === LOSS: 0.010996609926223755
# EPOCH 484 === BATCH: 4 === LOSS: 0.009517624974250793
# EPOCH 484 === BATCH: 5 === LOSS: 0.01145193912088871
# EPOCH 484 === BATCH: 6 === LOSS: 0.03891710191965103
# EPOCH 484 === BATCH: 7 === LOSS: 0.006894269026815891
# EPOCH 484 === BATCH: 8 === LOSS: 0.024172350764274597
# EPOCH 484 === BATCH: 9 === LOSS: 0.007751639932394028
# EPOCH 484 === BATCH: 10 === LOSS: 0.03385862335562706
# EPOCH 484 === BATCH: 11 === LOSS: 0.019595356658101082
# EPOCH 484 === BATCH: 12 === LOSS: 0.018879607319831848
# EPOCH 484 === BATCH: 13 === LOSS: 0.007522528059780598
# EPOCH 484 === BATCH: 14 === LOSS: 0.008929142728447914
# EPOCH 484 === BATCH: 15 === LOSS: 0.04516083002090454
# EPOCH 484 === BATCH: 16 === LOSS: 0.007853424176573753
# EPOCH 484 LOSS: 0.017427604063414037
# EPOCH 485 === BATCH: 1 === LOSS: 0.006228967569768429
# EPOCH 485 === BATCH: 2 === LOSS: 0.030846986919641495
# EPOCH 485 === BATCH: 3 === LOSS: 0.01900745928287506
# EPOCH 485 === BATCH: 4 === LOSS: 0.02314816229045391
# EPOCH 485 === BATCH: 5 === LOSS: 0.0060068899765610695
# EPOCH 485 === BATCH: 6 === LOSS: 0.007335652597248554
# EPOCH 485 === BATCH: 7 === LOSS: 0.02440910041332245
# EPOCH 485 === BATCH: 8 === LOSS: 0.012910512275993824
# EPOCH 485 === BATCH: 9 === LOSS: 0.0072074877098202705
# EPOCH 485 === BATCH: 10 === LOSS: 0.009314753115177155
# EPOCH 485 === BATCH: 11 === LOSS: 0.016468195244669914
# EPOCH 485 === BATCH: 12 === LOSS: 0.04637499898672104
# EPOCH 485 === BATCH: 13 === LOSS: 0.013328110799193382
# EPOCH 485 === BATCH: 14 === LOSS: 0.02097896672785282
# EPOCH 485 === BATCH: 15 === LOSS: 0.021796613931655884
# EPOCH 485 === BATCH: 16 === LOSS: 0.008157871663570404
# EPOCH 485 LOSS: 0.017095045594032854
# EPOCH 486 === BATCH: 1 === LOSS: 0.035149794071912766
# EPOCH 486 === BATCH: 2 === LOSS: 0.006397175136953592
# EPOCH 486 === BATCH: 3 === LOSS: 0.019286373630166054
# EPOCH 486 === BATCH: 4 === LOSS: 0.023643001914024353
# EPOCH 486 === BATCH: 5 === LOSS: 0.011752714402973652
# EPOCH 486 === BATCH: 6 === LOSS: 0.006134816445410252
# EPOCH 486 === BATCH: 7 === LOSS: 0.020322531461715698
# EPOCH 486 === BATCH: 8 === LOSS: 0.004445049911737442
# EPOCH 486 === BATCH: 9 === LOSS: 0.01811610721051693
# EPOCH 486 === BATCH: 10 === LOSS: 0.033936940133571625
# EPOCH 486 === BATCH: 11 === LOSS: 0.0044943527318537235
# EPOCH 486 === BATCH: 12 === LOSS: 0.006448153406381607
# EPOCH 486 === BATCH: 13 === LOSS: 0.02624441310763359
# EPOCH 486 === BATCH: 14 === LOSS: 0.019918210804462433
# EPOCH 486 === BATCH: 15 === LOSS: 0.0072197625413537025
# EPOCH 486 === BATCH: 16 === LOSS: 0.03911203518509865
# EPOCH 486 LOSS: 0.01766383950598538
# EPOCH 487 === BATCH: 1 === LOSS: 0.013929995708167553
# EPOCH 487 === BATCH: 2 === LOSS: 0.0065566315315663815
# EPOCH 487 === BATCH: 3 === LOSS: 0.00927647389471531
# EPOCH 487 === BATCH: 4 === LOSS: 0.025859002023935318
# EPOCH 487 === BATCH: 5 === LOSS: 0.02077472023665905
# EPOCH 487 === BATCH: 6 === LOSS: 0.0038993849884718657
# EPOCH 487 === BATCH: 7 === LOSS: 0.02127743326127529
# EPOCH 487 === BATCH: 8 === LOSS: 0.04529187083244324
# EPOCH 487 === BATCH: 9 === LOSS: 0.00871395505964756
# EPOCH 487 === BATCH: 10 === LOSS: 0.035653576254844666
# EPOCH 487 === BATCH: 11 === LOSS: 0.03308111056685448
# EPOCH 487 === BATCH: 12 === LOSS: 0.008301151916384697
# EPOCH 487 === BATCH: 13 === LOSS: 0.007451201789081097
# EPOCH 487 === BATCH: 14 === LOSS: 0.00692397728562355
# EPOCH 487 === BATCH: 15 === LOSS: 0.0067377761006355286
# EPOCH 487 === BATCH: 16 === LOSS: 0.02388148382306099
# EPOCH 487 LOSS: 0.01735060907958541
# EPOCH 488 === BATCH: 1 === LOSS: 0.04314021021127701
# EPOCH 488 === BATCH: 2 === LOSS: 0.008223406970500946
# EPOCH 488 === BATCH: 3 === LOSS: 0.009148799814283848
# EPOCH 488 === BATCH: 4 === LOSS: 0.021967042237520218
# EPOCH 488 === BATCH: 5 === LOSS: 0.01254610251635313
# EPOCH 488 === BATCH: 6 === LOSS: 0.018879327923059464
# EPOCH 488 === BATCH: 7 === LOSS: 0.038062091916799545
# EPOCH 488 === BATCH: 8 === LOSS: 0.005582171957939863
# EPOCH 488 === BATCH: 9 === LOSS: 0.007373929023742676
# EPOCH 488 === BATCH: 10 === LOSS: 0.020151205360889435
# EPOCH 488 === BATCH: 11 === LOSS: 0.016914445906877518
# EPOCH 488 === BATCH: 12 === LOSS: 0.02039852924644947
# EPOCH 488 === BATCH: 13 === LOSS: 0.019604839384555817
# EPOCH 488 === BATCH: 14 === LOSS: 0.018555963411927223
# EPOCH 488 === BATCH: 15 === LOSS: 0.006970008369535208
# EPOCH 488 === BATCH: 16 === LOSS: 0.0026469978038221598
# EPOCH 488 LOSS: 0.016885317003470846
# EPOCH 489 === BATCH: 1 === LOSS: 0.006093895062804222
# EPOCH 489 === BATCH: 2 === LOSS: 0.007017774041742086
# EPOCH 489 === BATCH: 3 === LOSS: 0.0055367485620081425
# EPOCH 489 === BATCH: 4 === LOSS: 0.010386553592979908
# EPOCH 489 === BATCH: 5 === LOSS: 0.011797808110713959
# EPOCH 489 === BATCH: 6 === LOSS: 0.05466518551111221
# EPOCH 489 === BATCH: 7 === LOSS: 0.01180268358439207
# EPOCH 489 === BATCH: 8 === LOSS: 0.02084287814795971
# EPOCH 489 === BATCH: 9 === LOSS: 0.011744479648768902
# EPOCH 489 === BATCH: 10 === LOSS: 0.0413067489862442
# EPOCH 489 === BATCH: 11 === LOSS: 0.0069525642320513725
# EPOCH 489 === BATCH: 12 === LOSS: 0.03606696054339409
# EPOCH 489 === BATCH: 13 === LOSS: 0.011094975285232067
# EPOCH 489 === BATCH: 14 === LOSS: 0.006310902535915375
# EPOCH 489 === BATCH: 15 === LOSS: 0.011462169699370861
# EPOCH 489 === BATCH: 16 === LOSS: 0.02296755090355873
# EPOCH 489 LOSS: 0.017253117403015494
# EPOCH 490 === BATCH: 1 === LOSS: 0.008819562382996082
# EPOCH 490 === BATCH: 2 === LOSS: 0.011398456990718842
# EPOCH 490 === BATCH: 3 === LOSS: 0.006652659270912409
# EPOCH 490 === BATCH: 4 === LOSS: 0.010747436434030533
# EPOCH 490 === BATCH: 5 === LOSS: 0.017577562481164932
# EPOCH 490 === BATCH: 6 === LOSS: 0.02024311013519764
# EPOCH 490 === BATCH: 7 === LOSS: 0.009683212265372276
# EPOCH 490 === BATCH: 8 === LOSS: 0.006079437676817179
# EPOCH 490 === BATCH: 9 === LOSS: 0.007827847264707088
# EPOCH 490 === BATCH: 10 === LOSS: 0.008922100067138672
# EPOCH 490 === BATCH: 11 === LOSS: 0.02499159798026085
# EPOCH 490 === BATCH: 12 === LOSS: 0.0060594892129302025
# EPOCH 490 === BATCH: 13 === LOSS: 0.032297223806381226
# EPOCH 490 === BATCH: 14 === LOSS: 0.04198110103607178
# EPOCH 490 === BATCH: 15 === LOSS: 0.023023230955004692
# EPOCH 490 === BATCH: 16 === LOSS: 0.0512457937002182
# EPOCH 490 LOSS: 0.017971863853745162
# EPOCH 491 === BATCH: 1 === LOSS: 0.018306398764252663
# EPOCH 491 === BATCH: 2 === LOSS: 0.019435515627264977
# EPOCH 491 === BATCH: 3 === LOSS: 0.006684912834316492
# EPOCH 491 === BATCH: 4 === LOSS: 0.019453173503279686
# EPOCH 491 === BATCH: 5 === LOSS: 0.00582672655582428
# EPOCH 491 === BATCH: 6 === LOSS: 0.007408098317682743
# EPOCH 491 === BATCH: 7 === LOSS: 0.015618190169334412
# EPOCH 491 === BATCH: 8 === LOSS: 0.03328409045934677
# EPOCH 491 === BATCH: 9 === LOSS: 0.007784206420183182
# EPOCH 491 === BATCH: 10 === LOSS: 0.010924572125077248
# EPOCH 491 === BATCH: 11 === LOSS: 0.023596374318003654
# EPOCH 491 === BATCH: 12 === LOSS: 0.007756600622087717
# EPOCH 491 === BATCH: 13 === LOSS: 0.005299797281622887
# EPOCH 491 === BATCH: 14 === LOSS: 0.03588252142071724
# EPOCH 491 === BATCH: 15 === LOSS: 0.04251442477107048
# EPOCH 491 === BATCH: 16 === LOSS: 0.009984033182263374
# EPOCH 491 LOSS: 0.016859977273270488
# EPOCH 492 === BATCH: 1 === LOSS: 0.020848149433732033
# EPOCH 492 === BATCH: 2 === LOSS: 0.0204952210187912
# EPOCH 492 === BATCH: 3 === LOSS: 0.005065114237368107
# EPOCH 492 === BATCH: 4 === LOSS: 0.03449799492955208
# EPOCH 492 === BATCH: 5 === LOSS: 0.02580236829817295
# EPOCH 492 === BATCH: 6 === LOSS: 0.018958883360028267
# EPOCH 492 === BATCH: 7 === LOSS: 0.004736635833978653
# EPOCH 492 === BATCH: 8 === LOSS: 0.021662116050720215
# EPOCH 492 === BATCH: 9 === LOSS: 0.0158479455858469
# EPOCH 492 === BATCH: 10 === LOSS: 0.006716112606227398
# EPOCH 492 === BATCH: 11 === LOSS: 0.006707255728542805
# EPOCH 492 === BATCH: 12 === LOSS: 0.00404260354116559
# EPOCH 492 === BATCH: 13 === LOSS: 0.03813190013170242
# EPOCH 492 === BATCH: 14 === LOSS: 0.01727120205760002
# EPOCH 492 === BATCH: 15 === LOSS: 0.02610066905617714
# EPOCH 492 === BATCH: 16 === LOSS: 0.004626832902431488
# EPOCH 492 LOSS: 0.01696943779825233
# EPOCH 493 === BATCH: 1 === LOSS: 0.006886906921863556
# EPOCH 493 === BATCH: 2 === LOSS: 0.046748533844947815
# EPOCH 493 === BATCH: 3 === LOSS: 0.018539361655712128
# EPOCH 493 === BATCH: 4 === LOSS: 0.01591608114540577
# EPOCH 493 === BATCH: 5 === LOSS: 0.015581089071929455
# EPOCH 493 === BATCH: 6 === LOSS: 0.018444377928972244
# EPOCH 493 === BATCH: 7 === LOSS: 0.012087186798453331
# EPOCH 493 === BATCH: 8 === LOSS: 0.007541152182966471
# EPOCH 493 === BATCH: 9 === LOSS: 0.009132253006100655
# EPOCH 493 === BATCH: 10 === LOSS: 0.01453164778649807
# EPOCH 493 === BATCH: 11 === LOSS: 0.017936300486326218
# EPOCH 493 === BATCH: 12 === LOSS: 0.018423035740852356
# EPOCH 493 === BATCH: 13 === LOSS: 0.009094968438148499
# EPOCH 493 === BATCH: 14 === LOSS: 0.005403188057243824
# EPOCH 493 === BATCH: 15 === LOSS: 0.022730495780706406
# EPOCH 493 === BATCH: 16 === LOSS: 0.04854319244623184
# EPOCH 493 LOSS: 0.017971235705772415
# EPOCH 494 === BATCH: 1 === LOSS: 0.02144971489906311
# EPOCH 494 === BATCH: 2 === LOSS: 0.006394051015377045
# EPOCH 494 === BATCH: 3 === LOSS: 0.016254443675279617
# EPOCH 494 === BATCH: 4 === LOSS: 0.005973300896584988
# EPOCH 494 === BATCH: 5 === LOSS: 0.047924064099788666
# EPOCH 494 === BATCH: 6 === LOSS: 0.019047286361455917
# EPOCH 494 === BATCH: 7 === LOSS: 0.01013852283358574
# EPOCH 494 === BATCH: 8 === LOSS: 0.010442567989230156
# EPOCH 494 === BATCH: 9 === LOSS: 0.024633988738059998
# EPOCH 494 === BATCH: 10 === LOSS: 0.00989713054150343
# EPOCH 494 === BATCH: 11 === LOSS: 0.007077614776790142
# EPOCH 494 === BATCH: 12 === LOSS: 0.03330417349934578
# EPOCH 494 === BATCH: 13 === LOSS: 0.031656742095947266
# EPOCH 494 === BATCH: 14 === LOSS: 0.007544218096882105
# EPOCH 494 === BATCH: 15 === LOSS: 0.0067820558324456215
# EPOCH 494 === BATCH: 16 === LOSS: 0.01457126159220934
# EPOCH 494 LOSS: 0.017068196058971807
# EPOCH 495 === BATCH: 1 === LOSS: 0.008087811060249805
# EPOCH 495 === BATCH: 2 === LOSS: 0.021653341129422188
# EPOCH 495 === BATCH: 3 === LOSS: 0.007844299077987671
# EPOCH 495 === BATCH: 4 === LOSS: 0.019056955352425575
# EPOCH 495 === BATCH: 5 === LOSS: 0.006013637874275446
# EPOCH 495 === BATCH: 6 === LOSS: 0.007744987495243549
# EPOCH 495 === BATCH: 7 === LOSS: 0.03523963689804077
# EPOCH 495 === BATCH: 8 === LOSS: 0.018879614770412445
# EPOCH 495 === BATCH: 9 === LOSS: 0.028766661882400513
# EPOCH 495 === BATCH: 10 === LOSS: 0.009273739531636238
# EPOCH 495 === BATCH: 11 === LOSS: 0.024902161210775375
# EPOCH 495 === BATCH: 12 === LOSS: 0.01481652818620205
# EPOCH 495 === BATCH: 13 === LOSS: 0.022454816848039627
# EPOCH 495 === BATCH: 14 === LOSS: 0.009501579217612743
# EPOCH 495 === BATCH: 15 === LOSS: 0.004825911018997431
# EPOCH 495 === BATCH: 16 === LOSS: 0.04600175470113754
# EPOCH 495 LOSS: 0.017816464765928686
# EPOCH 496 === BATCH: 1 === LOSS: 0.01400085724890232
# EPOCH 496 === BATCH: 2 === LOSS: 0.005700049456208944
# EPOCH 496 === BATCH: 3 === LOSS: 0.008119411766529083
# EPOCH 496 === BATCH: 4 === LOSS: 0.037707410752773285
# EPOCH 496 === BATCH: 5 === LOSS: 0.03499902784824371
# EPOCH 496 === BATCH: 6 === LOSS: 0.01947067864239216
# EPOCH 496 === BATCH: 7 === LOSS: 0.018294597044587135
# EPOCH 496 === BATCH: 8 === LOSS: 0.0058301459066569805
# EPOCH 496 === BATCH: 9 === LOSS: 0.025184903293848038
# EPOCH 496 === BATCH: 10 === LOSS: 0.020592590793967247
# EPOCH 496 === BATCH: 11 === LOSS: 0.0045304009690880775
# EPOCH 496 === BATCH: 12 === LOSS: 0.007001037709414959
# EPOCH 496 === BATCH: 13 === LOSS: 0.019906336441636086
# EPOCH 496 === BATCH: 14 === LOSS: 0.0062406063079833984
# EPOCH 496 === BATCH: 15 === LOSS: 0.03003171645104885
# EPOCH 496 === BATCH: 16 === LOSS: 0.008295362815260887
# EPOCH 496 LOSS: 0.016619070840533823
# EPOCH 497 === BATCH: 1 === LOSS: 0.019567862153053284
# EPOCH 497 === BATCH: 2 === LOSS: 0.0116895642131567
# EPOCH 497 === BATCH: 3 === LOSS: 0.004312693141400814
# EPOCH 497 === BATCH: 4 === LOSS: 0.02089390717446804
# EPOCH 497 === BATCH: 5 === LOSS: 0.010480023920536041
# EPOCH 497 === BATCH: 6 === LOSS: 0.01281590573489666
# EPOCH 497 === BATCH: 7 === LOSS: 0.03406524658203125
# EPOCH 497 === BATCH: 8 === LOSS: 0.020570995286107063
# EPOCH 497 === BATCH: 9 === LOSS: 0.0071385325863957405
# EPOCH 497 === BATCH: 10 === LOSS: 0.01949779875576496
# EPOCH 497 === BATCH: 11 === LOSS: 0.009177315980196
# EPOCH 497 === BATCH: 12 === LOSS: 0.03161187469959259
# EPOCH 497 === BATCH: 13 === LOSS: 0.029350483790040016
# EPOCH 497 === BATCH: 14 === LOSS: 0.008832847699522972
# EPOCH 497 === BATCH: 15 === LOSS: 0.02027943730354309
# EPOCH 497 === BATCH: 16 === LOSS: 0.008060269057750702
# EPOCH 497 LOSS: 0.016771547379903495
# EPOCH 498 === BATCH: 1 === LOSS: 0.008308392949402332
# EPOCH 498 === BATCH: 2 === LOSS: 0.01761140488088131
# EPOCH 498 === BATCH: 3 === LOSS: 0.02164442092180252
# EPOCH 498 === BATCH: 4 === LOSS: 0.010221158154308796
# EPOCH 498 === BATCH: 5 === LOSS: 0.005536908283829689
# EPOCH 498 === BATCH: 6 === LOSS: 0.012138563208281994
# EPOCH 498 === BATCH: 7 === LOSS: 0.020459992811083794
# EPOCH 498 === BATCH: 8 === LOSS: 0.01010530348867178
# EPOCH 498 === BATCH: 9 === LOSS: 0.042515985667705536
# EPOCH 498 === BATCH: 10 === LOSS: 0.011140621267259121
# EPOCH 498 === BATCH: 11 === LOSS: 0.029002096503973007
# EPOCH 498 === BATCH: 12 === LOSS: 0.012372375465929508
# EPOCH 498 === BATCH: 13 === LOSS: 0.02173708751797676
# EPOCH 498 === BATCH: 14 === LOSS: 0.017994094640016556
# EPOCH 498 === BATCH: 15 === LOSS: 0.01856696419417858
# EPOCH 498 === BATCH: 16 === LOSS: 0.010998633690178394
# EPOCH 498 LOSS: 0.01689712522784248
# EPOCH 499 === BATCH: 1 === LOSS: 0.005249063018709421
# EPOCH 499 === BATCH: 2 === LOSS: 0.042079705744981766
# EPOCH 499 === BATCH: 3 === LOSS: 0.009078179486095905
# EPOCH 499 === BATCH: 4 === LOSS: 0.01082039438188076
# EPOCH 499 === BATCH: 5 === LOSS: 0.0076008872129023075
# EPOCH 499 === BATCH: 6 === LOSS: 0.011529693379998207
# EPOCH 499 === BATCH: 7 === LOSS: 0.029568955302238464
# EPOCH 499 === BATCH: 8 === LOSS: 0.007535659708082676
# EPOCH 499 === BATCH: 9 === LOSS: 0.030563876032829285
# EPOCH 499 === BATCH: 10 === LOSS: 0.010592568665742874
# EPOCH 499 === BATCH: 11 === LOSS: 0.023351434618234634
# EPOCH 499 === BATCH: 12 === LOSS: 0.016348566859960556
# EPOCH 499 === BATCH: 13 === LOSS: 0.02127719298005104
# EPOCH 499 === BATCH: 14 === LOSS: 0.0180670078843832
# EPOCH 499 === BATCH: 15 === LOSS: 0.020178304985165596
# EPOCH 499 === BATCH: 16 === LOSS: 0.01353166438639164
# EPOCH 499 LOSS: 0.01733582216547802
# EPOCH 500 === BATCH: 1 === LOSS: 0.006358380429446697
# EPOCH 500 === BATCH: 2 === LOSS: 0.02011803537607193
# EPOCH 500 === BATCH: 3 === LOSS: 0.031790219247341156
# EPOCH 500 === BATCH: 4 === LOSS: 0.00833053607493639
# EPOCH 500 === BATCH: 5 === LOSS: 0.007309952285140753
# EPOCH 500 === BATCH: 6 === LOSS: 0.005276666488498449
# EPOCH 500 === BATCH: 7 === LOSS: 0.01994761824607849
# EPOCH 500 === BATCH: 8 === LOSS: 0.005543007515370846
# EPOCH 500 === BATCH: 9 === LOSS: 0.02135142870247364
# EPOCH 500 === BATCH: 10 === LOSS: 0.03364407643675804
# EPOCH 500 === BATCH: 11 === LOSS: 0.02012665383517742
# EPOCH 500 === BATCH: 12 === LOSS: 0.018787143751978874
# EPOCH 500 === BATCH: 13 === LOSS: 0.02453695237636566
# EPOCH 500 === BATCH: 14 === LOSS: 0.023161817342042923
# EPOCH 500 === BATCH: 15 === LOSS: 0.007288183085620403
# EPOCH 500 === BATCH: 16 === LOSS: 0.010843822732567787
# EPOCH 500 LOSS: 0.01652590587036684

# %%
torch.save(model.state_dict(), os.path.join("saved_models", "FingerCounter(alp-1).pth"))

# %%
del model

# %% [markdown]
# # Model Evaluation

# %%
import torch
import torch.nn as nn

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import classification_report

# %%
model = nn.Sequential(
        nn.Linear(63, 16),
        nn.ReLU(),
        nn.Linear(16, 5),
        nn.Softmax(dim=1)
    )

# %%
model.load_state_dict(torch.load(os.path.join("saved_models", "FingerCounter(alp-1).pth")))
# Out:
# C:\Users\mainm\AppData\Local\Temp\ipykernel_25760\3970515037.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(os.path.join("saved_models", "FingerCounter(alp-1).pth")))
# <All keys matched successfully>

# %%
model.eval()
# Out:
# Sequential(
#   (0): Linear(in_features=63, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=16, out_features=5, bias=True)
#   (3): Softmax(dim=1)
# )

# %%
pred = model(torch.tensor(x_test).float()).detach().numpy()
print("PRED:", pred.shape)
print("Y_TEST:", y_test.shape)
# Out:
# PRED: (75, 5)
# Y_TEST: (75, 5)

# %%
predicted = np.argmax(pred, axis=-1) + 1
actual = np.argmax(y_test, axis=-1) + 1

# %%
confusion_matrix(actual, predicted)
# Out:
# array([[21,  1,  0,  0,  0],
#        [ 0, 11,  0,  0,  0],
#        [ 0,  1,  7,  0,  0],
#        [ 0,  0,  0, 17,  0],
#        [ 0,  0,  0,  0, 17]], dtype=int64)

# %%
for i, matrix in enumerate(multilabel_confusion_matrix(actual, predicted)):
    print("=========================")
    print(f"Rest vs. \"{digits[i]}\":")
    print(matrix)
    print("=========================\n")
# Out:
# =========================
# Rest vs. "one":
# [[53  0]
#  [ 1 21]]
# =========================
#
# =========================
# Rest vs. "two":
# [[62  2]
#  [ 0 11]]
# =========================
#
# =========================
# Rest vs. "three":
# [[67  0]
#  [ 1  7]]
# =========================
#
# =========================
# Rest vs. "four":
# [[58  0]
#  [ 0 17]]
# =========================
#
# =========================
# Rest vs. "five":
# [[58  0]
#  [ 0 17]]
# =========================

# %%
print(classification_report(actual, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.98        22
#            2       0.85      1.00      0.92        11
#            3       1.00      0.88      0.93         8
#            4       1.00      1.00      1.00        17
#            5       1.00      1.00      1.00        17
#
#     accuracy                           0.97        75
#    macro avg       0.97      0.97      0.97        75
# weighted avg       0.98      0.97      0.97        75
